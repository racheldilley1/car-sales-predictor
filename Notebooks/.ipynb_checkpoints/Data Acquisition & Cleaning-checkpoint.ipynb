# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import datetime
import time
from fake_useragent import UserAgent 
ua = UserAgent()
headers = {'user-agent': ua.random}

#data = requests.get(url, headers=headers)

# %%
def get_monthly_sales_df(url, year_str, tbl_num):
    '''
    Return a time series df of monthly US car sales for every make and model 
    '''
    response = requests.get(url, headers=headers)
    page= response.text
    soup = BeautifulSoup(page, "lxml")
    
    #find car sales data and turn it into a list
    tbl_str = soup.find_all('tbody')[tbl_num].text
    tbl_list = tbl_str.split('\n')
    tbl_list = [i for i in tbl_list if i] 
    
    #create empty time series df for specified year
    date_time_str = year_str + '-01'
    start_date = datetime.datetime.strptime(date_time_str, '%Y-%m')
    index = pd.date_range(start_date, periods=12, freq='m')
    df = pd.DataFrame(index=index)
    
    #fill empty df with monthly sales for all makes and models
    col_name = ''
    idx = 0
    for x in range(0,len(tbl_list)//13):
        col_name = tbl_list[x+idx]
        list_vals = []
        for val in range(x+1,x+13):
            list_vals.append(tbl_list[idx+val])
        df[col_name]=list_vals
        idx = idx+12
    return df

# %%
url = 'https://www.goodcarbadcar.net/2019-us-vehicle-sales-figures-by-model/'
df_sales = get_monthly_sales_df(url, '2019', 2)
url = 'https://www.goodcarbadcar.net/2020-us-vehicle-sales-figures-by-model/'
df = get_monthly_sales_df(url, '2020', 1)
monthly_sales_df = pd.concat((df_sales, df))
#monthly_sales_df.columns

# %%
def get_model_sales_df(url, year):
    response = requests.get(url, headers=headers)
    page = response.text
    df_list = pd.read_html(page)
    
    if len(df_list) == 1 or year == '2019':
        df = pd.DataFrame(df_list[0])
    elif len(df_list) == 2:
        df = pd.DataFrame(df_list[1])
    else:
        df = pd.DataFrame(df_list[len(df_list)-1])
    
    #special case for 2020 data because most recent
    if year == '2020':  
        soup = BeautifulSoup(page, "lxml")
    
        #find car sales data and turn it into a list
        tbl_str = soup.find_all('tbody')[1].text
        tbl_list = tbl_str.split('\n')
        tbl_list = [i for i in tbl_list if i] 
        
        columns = ('Model',year)
        df = pd.DataFrame(columns=columns)

        #fill empty df with monthly sales for all makes and models
        model_name = ''
        idx = 0
        index = 0
        for x in range(0,len(tbl_list)//13):
            model_name = tbl_list[x+idx]
            year_sum = 0
            for val in range(x+1,x+13):
                month_total = tbl_list[idx+val].replace(',','')
                month_total = int(month_total)
                year_sum = year_sum + month_total
            #df1 = pd.DataFrame([model_name, year_sum], columns = ['Model', year])
            df = df.append(pd.DataFrame({'Model': model_name, year: year_sum}, index=[index]), ignore_index=True)
            index = index+1
            #df.append(df1)
            idx = idx+12
        return df
    
    if year == '2012':
        df = df.iloc[:, [2,3]]
    elif year == '2005':
        df = df.iloc[:, [1,3]]
    elif year in ['2017','2018', '2019', '2020']:
        df = df.iloc[:, [0,4]]
    else:
        df = df.iloc[:, [1,2]]
    df.columns = ['Model', year]
    
    #* indicate further breakdown of sum totals, overall totals be removed further down when duplicates are removed
    #other symbols refer to subnotes in the tables and are not apart of model names
    symbols = ['*', '²', '¹', '^', '†', '‡']
    
    for s in symbols:
        df['Model'] = df['Model'].str.replace(s,'')

    df.dropna(subset=['Model'], inplace=True)
    
    df['Model'] = df['Model'].str.rstrip()
    df['Model'] = df['Model'].str.lstrip()
    
    #remove first in set of duplicates b/c first is a sum of a car and the hybrid model
    
    df.drop_duplicates(subset='Model', keep='last', inplace=True)
    
    df[year] = df[year].apply(pd.to_numeric, errors='coerce')
    
    return df

# %%
url = 'https://www.goodcarbadcar.net/2006-usa-auto-sales-rankings-by-mode/'
yearly_sales_df= get_model_sales_df(url = url, year = '2005')
# Out:
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')

# %%
url_dict = {'2006': 'https://www.goodcarbadcar.net/2006-usa-auto-sales-rankings-by-mode/',
            '2007': 'https://www.goodcarbadcar.net/usa-2007-vehicle-sales-rankings-by-mode/',
            '2008': 'https://www.goodcarbadcar.net/2008-america-auto-sales-rankings-by-mode/',
            '2009': 'https://www.goodcarbadcar.net/usa-auto-sales-rankings-by-model-2009/',
            '2010': 'https://www.goodcarbadcar.net/2010-america-auto-sales-rankings-by-mode/',
            '2011': 'https://www.goodcarbadcar.net/top-268-best-selling-vehicles-2011-year/',
            '2012': 'https://www.goodcarbadcar.net/2012-usa-auto-sales-rankings-by-model7/',
            '2013': 'https://www.goodcarbadcar.net/usa-vehicle-sales-rankings-by-model-december-2013-year-end/',
            '2014': 'https://www.goodcarbadcar.net/usa-all-cars-sales-figures-2014-december-year-end/',
            '2015': 'https://www.goodcarbadcar.net/usa-car-sales-by-model-2015-year-end-december/',
            '2016': 'https://www.goodcarbadcar.net/usa-2016-vehicle-sales-by-model-manufacturer-brand/',
            '2017': 'https://www.goodcarbadcar.net/december-2017-year-end-u-s-passenger-car-sales-rankings-top-171-best-selling-cars-america-every-car-ranked/',
            '2018': 'https://www.goodcarbadcar.net/december-2018-the-best-selling-vehicles-in-america-every-vehicle-ranked/',
            '2019': 'https://www.goodcarbadcar.net/2019-us-vehicle-sales-figures-by-model/',
            '2020': 'https://www.goodcarbadcar.net/2020-us-vehicle-sales-figures-by-model/'
           }

years = ['2006']
for key, value in url_dict.items():
    #print(key)
    years.append(key)
    df= get_model_sales_df(url = value, year = key)
    #print(df)
    yearly_sales_df = pd.merge(yearly_sales_df, df, on='Model', how='outer')
    #print(yearly_sales_df[yearly_sales_df.Model.str.contains("Toyota")])
# Out:
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')
# <ipython-input-4-020ed057bbbb>:58: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['Model'] = df['Model'].str.replace(s,'')

# %%
columns = ('Model','Total_Sales')
total_sales_df = pd.DataFrame(columns=columns)
total_sales_df = total_sales_df.fillna(0)
total_sales_df['Model'] = yearly_sales_df['Model']

total_sales_df['Total_Sales'] = yearly_sales_df[years].sum(axis=1)
#print(total_sales_df)

# %%
total_sales_df.sort_values('Total_Sales', ascending=False, inplace=True)
total_sales_df = total_sales_df[total_sales_df.Total_Sales != 0]

remove_strings = ["Market",'Total','Family','Brand','Passenger Cars, SUVs, Crossovers','Minivans','Pickup Trucks',
                 'Commercial Vans', 'COMPANY', 'MOTOR', 'GROUP', 'AMERICAN', 'AUTOMOBILES', 'JAGUAR', 'DAIMLER']

for string in remove_strings:
    total_sales_df = total_sales_df[~total_sales_df.Model.str.contains(string)]

#total_sales_df = total_sales_df[total_sales_df.Model != '*Market*']
total_sales_df
# Out:
#                         Model  Total_Sales
# 0               Ford F-Series    9147816.0
# 1         Chevrolet Silverado    6685079.0
# 2                Toyota Camry    6221548.0
# 6                 Honda Civic    5009981.0
# 5                Honda Accord    4943796.0
# ..                        ...          ...
# 301  Mitsubishi Montero Sport          2.0
# 300             Mazda Protege          2.0
# 299      Land Rover Discovery          2.0
# 302             Suzuki Esteem          2.0
# 389              Buick Verona          1.0
#
# [671 rows x 2 columns]

# %%
def get_brand_links(org_url):
    #org_url = 'https://www.carspecs.us/'
    response = requests.get(org_url, headers=headers)
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    #tbl = soup.find_all(class_='modelnamesandmakes_item')
    #link_list = soup.find_all(id_ = 'homepage-browsemakes')
    brand_link_dict = dict()
    link_list = soup.find_all('li')
    for x in link_list[7:]:
        brand = x.text
        link = 'https://www.carspecs.us' + x.find('a')['href']
        brand_link_dict[brand] = link
        time.sleep(1)
    return brand_link_dict

# %%
def get_model_links(brand, url):
    #url = 'https://www.carspecs.us/cars/acura'
    response = requests.get(url, headers=headers)
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    div_list = soup.find_all('div', class_='pure-u-1 pure-u-md-1-2')
    #print(div_list[1].find_all('li'))
    model_link_dict = dict()
    for x in div_list[1].find_all('li'):
        model = brand + ' ' + x.text
        link = org_url + x.find('a')['href']
        response = requests.get(link)
        page = response.text
        soup = BeautifulSoup(page, "lxml")
        year_links = soup.find_all('li')
        year = int(year_links[7].text)
        if year > 2004:
            #print(year)
            model_link = 'https://www.carspecs.us' + year_links[7].find('a')['href']

            model_link_dict[model] = model_link
            time.sleep(1)

    return model_link_dict

# %%
def get_model_specs(url):
#url = 'https://www.carspecs.us//cars/2020/acura/mdx'
    response = requests.get(url, headers=headers)
    page = response.text
    soup = BeautifulSoup(page, "lxml")

    doors =passengers =speed =horsepower =drive =mpg =engine =tank =volume =length =width =height = float('NaN')
    
    try:
        price = soup.find(text=re.compile('starting from'))
        price = price.findNext().text
    
    except:
        price = float('NaN')
    
    div_list = soup.find('div', class_='car-details').find_all('div')
    #print(div_list)

    for div in div_list[1:]:
        spec_list = div.text.split('\n')
        spec_list = [i for i in spec_list if i]
        #print(spec_list)
        if spec_list:
            if 'RPM' not in spec_list[0]:
                if 'Passenger Doors' in spec_list[0]:
                    doors = int(spec_list[-1])
                if 'Passenger Capacity' in spec_list[0]:
                    passengers = int(spec_list[-1])
                if 'mph' in spec_list[0]:
                    speed = spec_list[-1]
                if 'Horsepower' in spec_list[0]:
                    horsepower = spec_list[-1]
                if 'Drive type' in spec_list[0]:
                    drive = spec_list[-1]
                if 'combined' in spec_list[0]:
                    mpg = spec_list[-1]
                if 'Combined' in spec_list[0]:
                    mpg = spec_list[-1]
                if 'Engine type' in spec_list[0]:
                    engine = spec_list[-1]
                    engine = engine.replace('\t', '')
                if 'tank capacity' in spec_list[0]:
                    tank = spec_list[-1]
                if 'EPA interior' in spec_list[0]:
                    volume = spec_list[-1]
                if 'Length' in spec_list[0]:
                    length = spec_list[-1]
                if 'Width' in spec_list[0]:
                    width = spec_list[-1]
                if 'Height' in spec_list[0]:
                    height = spec_list[-1]
        
        if mpg == '':
            mpg = soup.find(text=re.compile('highway mpg'))
            try:
                mpg_list = mpg.split('/ ')
                city = mpg_list[0].lstrip('\r\n ')
                highway = mpg_list[1]
                mpg = (int(city[0:2])+int(highway[0:2]))/2
            except:
                mpg = 0
    
    return [price, doors, passengers, speed, horsepower, drive, mpg, engine, tank, volume, length, width, height]

# %%
org_url = 'https://www.carspecs.us/'
brand_links = get_brand_links(org_url)
#print(brand_links)
all_model_links = dict()
for key, value in brand_links.items():
    all_model_links.update(get_model_links(key, brand_links[key]))
    #print(all_model_links)
#rint(all_model_links)

# %%
columns = ('Model', 'url', 'price', 'doors', 'passengers', 'speed_sec', 'horsepower_hp', 'drive', 'mpg', 'engine', 
           'tank_gal', 'volume_cuft', 'length_in', 'width_in', 'height_in')
model_spec_df = pd.DataFrame(columns=columns) 
idx = 0
for key, value in all_model_links.items():
    specs = get_model_specs(value)
    print(specs)
    print(value)
    model_spec_df = model_spec_df.append(pd.DataFrame({'Model': key, 'url': value, 'price': specs[0],'doors': specs[1],
                                                      'passengers': specs[2],'speed_sec': specs[3], 'horsepower_hp': specs[4],
                                                       'drive': specs[5],'mpg': specs[6],'engine': specs[7],
                                                       'tank_gal': specs[8], 'volume_cuft': specs[9], 'length_in': specs[10],
                                                      'width_in': specs[11],'height_in': specs[12]}, index=[idx]), ignore_index=True)
    idx = idx +1
    #print(model_spec_df)
# Out:
# ['$25,900', 4, 5, '6.63 sec', '201 hp', 'Front Wheel Drive ', '28 mpg', 'Gas', '13.20 gal.', '89.30 cu.ft.', '182.20 in.', '70.60 ', '55.60 in.']
# https://www.carspecs.us/cars/2020/acura/ilx
# [nan, nan, nan, '11.40 sec', '111 hp', ' Front wheel drive  ', nan, 'Hybrid', '13.20 gal.', '99.30 cu.ft.', '179.10 in.', '70.60 ', '55.60 in.']
# https://www.carspecs.us/cars/2014/acura/ilx-hybrid
# ['$46,500', 4, 7, '6.43 sec', '290 hp', 'All Wheel Drive ', '22 mpg', 'Gas', '19.50 gal.', '132.70 cu.ft.', '196.20 in.', '77.70 ', '67.40 in.']
# https://www.carspecs.us/cars/2020/acura/mdx
# ['$157,500', 2, 2, '3.17 sec', '573 hp', 'All Wheel Drive ', '21 mpg', 'Gas', '15.60 gal.', '44.00 cu.ft.', '176.00 in.', '76.30 ', '47.80 in.']
# https://www.carspecs.us/cars/2020/acura/nsx
# ['$46,000', 4, 5, '6.48 sec', '272 hp', 'All Wheel Drive ', '23 mpg', 'Gas', '17.10 gal.', '104.00 cu.ft.', '186.70 in.', '74.80 ', '65.70 in.']
# https://www.carspecs.us/cars/2020/acura/rdx
# ['$19,280', nan, nan, '6.10 sec', '300 hp', ' All wheel drive  ', nan, 'Gas', '19.30 gal.', '112.20 cu.ft.', '195.70 in.', '72.70 ', '57.20 in.']
# https://www.carspecs.us/cars/2012/acura/rl
# ['$54,900', 4, 5, '6.59 sec', '310 hp', 'Front Wheel Drive ', '23 mpg', 'Gas', '18.50 gal.', '102.10 cu.ft.', '198.10 in.', '74.40 ', '57.70 in.']
# https://www.carspecs.us/cars/2020/acura/rlx
# ['$3,396', 2, 4, '8.54 sec', '155 hp', 'Front Wheel Drive ', nan, 'Gas', '13.20 gal.', nan, '172.40 in.', '67.90 ', '54.90 in.']
# https://www.carspecs.us/cars/2006/acura/rsx
# ['$24,336', 4, 5, '6.83 sec', '280 hp', 'Front Wheel Drive ', '23 mpg', 'Gas', '18.50 gal.', nan, '194.00 in.', '74.00 ', '57.20 in.']
# https://www.carspecs.us/cars/2014/acura/tl
# ['$39,400', 4, 5, '7.21 sec', '206 hp', 'Front Wheel Drive ', '26 mpg', 'Gas', '17.20 gal.', '93.30 cu.ft.', '191.00 in.', '73.00 ', '57.00 in.']
# https://www.carspecs.us/cars/2020/acura/tlx
# ['$17,768', nan, nan, '8.25 sec', '201 hp', ' Front wheel drive  ', nan, 'Gas', '18.50 gal.', '108.50 cu.ft.', '185.60 in.', '72.40 ', '56.70 in.']
# https://www.carspecs.us/cars/2014/acura/tsx
# ['$20,668', nan, nan, '8.43 sec', '201 hp', ' Front wheel drive  ', nan, 'Gas', '18.50 gal.', '125.90 cu.ft.', '189.20 in.', '72.40 ', '57.90 in.']
# https://www.carspecs.us/cars/2014/acura/tsx-sport-wagon
# ['$24,950', 4, 5, '6.47 sec', '300 hp', 'All Wheel Drive ', '19 mpg', 'Gas', '21.00 gal.', nan, '192.40 in.', '78.50 ', '62.80 in.']
# https://www.carspecs.us/cars/2013/acura/zdx
# ['$67,150', 2, 2, '4.87 sec', '237 hp', 'Rear Wheel Drive ', '28 mpg', 'Gas', '10.60 gal.', nan, '157.00 in.', '73.50 ', '46.60 in.']
# https://www.carspecs.us/cars/2020/alfa-romeo/4c
# ['$65,900', 2, 2, '4.87 sec', '237 hp', 'Rear Wheel Drive ', nan, 'Gas', '10.50 gal.', nan, '157.00 in.', '73.50 ', '46.60 in.']
# https://www.carspecs.us/cars/2018/alfa-romeo/4c-spider
# ['$39,400', 4, 5, '6.00 sec', '280 hp', 'Rear Wheel Drive ', '27 mpg', 'Gas', '15.30 gal.', '95.40 cu.ft.', '182.50 in.', '73.70 ', '56.50 in.']
# https://www.carspecs.us/cars/2020/alfa-romeo/giulia
# ['$43,400', 4, 5, '6.33 sec', '280 hp', 'All Wheel Drive ', '24 mpg', 'Gas', '16.90 gal.', '116.10 cu.ft.', '184.60 in.', '74.90 ', '66.00 in.']
# https://www.carspecs.us/cars/2020/alfa-romeo/stelvio
# ['$241,000', 2, 4, '3.68 sec', '630 hp', 'Rear Wheel Drive ', nan, 'Gas', '20.50 gal.', nan, '186.60 in.', '76.80 ', '50.80 in.']
# https://www.carspecs.us/cars/2019/aston-martin/db11
# ['$190,598', 2, 4, '3.71 sec', '540 hp', 'Rear Wheel Drive ', '15 mpg', 'Gas', '20.60 gal.', nan, '185.80 in.', '74.00 ', '50.50 in.']
# https://www.carspecs.us/cars/2016/aston-martin/db9
# ['$46,612', nan, nan, '4.07 sec', '470 hp', 'rear-wheel ', nan, nan, '21.10 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2009/aston-martin/db9-base-hardtop
# [nan, nan, nan, '3.98 sec', '540 hp', ' Rear wheel drive  ', nan, 'Gas', '20.60 gal.', '83.00 cu.ft.', '185.80 in.', nan, '50.50 in.']
# https://www.carspecs.us/cars/2016/aston-martin/db9-gt
# ['$113,830', nan, nan, '3.72 sec', '510 hp', ' Rear wheel drive  ', nan, 'Gas', '21.10 gal.', nan, '185.80 in.', '75.00 ', '50.40 in.']
# https://www.carspecs.us/cars/2012/aston-martin/dbs
# ['$204,950', 4, 4, '4.18 sec', '565 hp', 'Rear Wheel Drive ', '17 mpg', 'Gas', '23.90 gal.', '83.00 cu.ft.', '197.60 in.', '75.90 ', '53.50 in.']
# https://www.carspecs.us/cars/2017/aston-martin/rapide
# [nan, nan, nan, '4.25 sec', '552 hp', ' Rear wheel drive  ', nan, 'Gas', '23.90 gal.', '97.00 cu.ft.', '197.60 in.', '75.90 ', '53.50 in.']
# https://www.carspecs.us/cars/2017/aston-martin/rapide-s
# ['$41,600', nan, nan, '3.73 sec', '520 hp', ' Rear wheel drive  ', nan, 'Gas', '22.00 gal.', nan, '183.70 in.', '75.70 ', '51.90 in.']
# https://www.carspecs.us/cars/2006/aston-martin/v12-vanquish
# ['$150,898', 2, 2, '3.65 sec', '565 hp', 'Rear Wheel Drive ', '14 mpg', 'Gas', '21.10 gal.', nan, '172.60 in.', '73.50 ', '49.20 in.']
# https://www.carspecs.us/cars/2016/aston-martin/v12-vantage
# [nan, nan, nan, '3.22 sec', '563 hp', ' Rear wheel drive  ', nan, 'Gas', '21.10 gal.', nan, '172.60 in.', '73.40 ', '49.20 in.']
# https://www.carspecs.us/cars/2017/aston-martin/v12-vantage-s
# ['$95,418', 2, 2, '4.22 sec', '430 hp', 'Rear Wheel Drive ', '15 mpg', 'Gas', '21.10 gal.', nan, '172.60 in.', '73.40 ', '50.00 in.']
# https://www.carspecs.us/cars/2016/aston-martin/v8-vantage
# ['$67,081', nan, nan, '4.07 sec', '430 hp', 'rear-wheel ', nan, nan, '21.20 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/aston-martin/v8-vantage-s
# ['$294,950', 2, 2, '3.70 sec', '580 hp', 'Rear Wheel Drive ', '16 mpg', 'Gas', '20.60 gal.', nan, '186.20 in.', '75.20 ', '51.00 in.']
# https://www.carspecs.us/cars/2019/aston-martin/vanquish
# [nan, nan, nan, '3.70 sec', '580 hp', ' Rear wheel drive  ', nan, 'Gas', '20.50 gal.', '83.00 cu.ft.', '186.20 in.', '75.20 ', '51.00 in.']
# https://www.carspecs.us/cars/2018/aston-martin/vanquish-s
# ['$149,995', 2, 2, nan, '503 hp', 'Rear Wheel Drive ', '21 mpg', 'Gas', '19.30 gal.', nan, '175.80 in.', '76.50 ', '50.10 in.']
# https://www.carspecs.us/cars/2019/aston-martin/vantage
# ['$83,158', 2, 4, '4.20 sec', '490 hp', 'Rear Wheel Drive ', '15 mpg', 'Gas', '21.10 gal.', '78.00 cu.ft.', '185.80 in.', '75.00 ', '50.40 in.']
# https://www.carspecs.us/cars/2012/aston-martin/virage
# ['$33,300', 4, 5, nan, '184 hp', 'Front Wheel Drive ', '30 mpg', 'Gas', '13.20 gal.', nan, '175.50 in.', '70.70 ', '55.70 in.']
# https://www.carspecs.us/cars/2020/audi/a3
# [nan, 2, 4, nan, '186 hp', 'Front Wheel Drive ', nan, 'Gas', '13.20 gal.', nan, '174.10 in.', '7.50 in.', '55.50 in.']
# https://www.carspecs.us/cars/2019/audi/a3-cabriolet
# ['$30,699', 4, 5, '8.40 sec', '204 hp', 'Front Wheel Drive ', '83 mpg', 'Gas', '10.60 gal.', nan, '169.80 in.', '70.30 ', '56.00 in.']
# https://www.carspecs.us/cars/2016/audi/a3-e-tron
# [nan, 4, 5, nan, '186 hp', 'Front Wheel Drive ', nan, 'Gas', '13.20 gal.', nan, '175.50 in.', '70.70 ', '55.70 in.']
# https://www.carspecs.us/cars/2019/audi/a3-sedan
# ['$40,650', 4, 5, '8.40 sec', '204 hp', 'Front Wheel Drive ', '36 mpg', 'Gas', '10.60 gal.', nan, '169.70 in.', '70.30 ', '56.10 in.']
# https://www.carspecs.us/cars/2018/audi/a3-sportback-e-tron
# ['$44,600', 4, 5, '5.90 sec', '248 hp', 'All Wheel Drive ', '26 mpg', 'Gas', '15.30 gal.', nan, '187.50 in.', '72.70 ', '58.80 in.']
# https://www.carspecs.us/cars/2020/audi/a4
# [nan, 4, 5, '5.81 sec', '252 hp', 'All Wheel Drive ', nan, 'Gas', '15.30 gal.', nan, '187.00 in.', '72.50 ', '58.80 in.']
# https://www.carspecs.us/cars/2019/audi/a4-allroad
# ['$49,900', 2, 4, '6.06 sec', '248 hp', 'All Wheel Drive ', '26 mpg', 'Gas', '15.30 gal.', '81.00 cu.ft.', '184.90 in.', '72.70 ', '54.50 in.']
# https://www.carspecs.us/cars/2020/audi/a5
# [nan, 4, 5, '5.67 sec', '252 hp', 'All Wheel Drive ', nan, 'Gas', '15.30 gal.', nan, '186.30 in.', '72.60 ', '54.60 in.']
# https://www.carspecs.us/cars/2019/audi/a5-sportback
# ['$73,900', 4, 5, '4.88 sec', '444 hp', 'All Wheel Drive ', '22 mpg', 'Gas', '19.30 gal.', nan, '195.00 in.', '74.30 ', '56.90 in.']
# https://www.carspecs.us/cars/2020/audi/a6
# ['$83,900', 4, 5, '4.97 sec', '444 hp', 'All Wheel Drive ', '22 mpg', 'Gas', '19.30 gal.', nan, '196.00 in.', '75.10 ', '55.80 in.']
# https://www.carspecs.us/cars/2020/audi/a7
# ['$85,200', 4, 5, '6.31 sec', '335 hp', 'All Wheel Drive ', '21 mpg', 'Gas', '21.70 gal.', nan, '208.70 in.', '76.60 ', '58.50 in.']
# https://www.carspecs.us/cars/2020/audi/a8
# ['$83,800', 4, 5, '5.82 sec', '335 hp', 'All Wheel Drive ', nan, 'Gas', '21.70 gal.', nan, '208.80 in.', '76.60 ', '58.60 in.']
# https://www.carspecs.us/cars/2019/audi/a8-l
# ['$34,587', 4, 5, '6.91 sec', '220 hp', 'All Wheel Drive ', '24 mpg', 'Gas', '16.10 gal.', nan, '185.90 in.', '72.50 ', '58.00 in.']
# https://www.carspecs.us/cars/2016/audi/allroad
# ['$34,587', 4, 5, '6.91 sec', '220 hp', 'All Wheel Drive ', '24 mpg', 'Gas', '16.10 gal.', nan, '185.90 in.', '72.50 ', '58.00 in.']
# https://www.carspecs.us/cars/2016/audi/allroad
# ['$6,037', nan, nan, '6.62 sec', '250 hp', ' All wheel drive  ', nan, 'Gas', '18.50 gal.', '99.30 cu.ft.', '189.40 in.', nan, '62.00 in.']
# https://www.carspecs.us/cars/2005/audi/allroad-quattro
# ['$74,800', 4, 5, '6.95 sec', '355 hp', 'All Wheel Drive ', '74 mpg', 'Electric', nan, nan, '193.00 in.', '76.30 ', '65.50 in.']
# https://www.carspecs.us/cars/2019/audi/e-tron
# ['$34,700', 4, 5, '7.24 sec', '228 hp', 'All Wheel Drive ', '22 mpg', 'Gas', '15.90 gal.', nan, '176.60 in.', '72.80 ', '62.90 in.']
# https://www.carspecs.us/cars/2020/audi/q3
# ['$52,900', 4, 5, '5.81 sec', '367 hp', 'All Wheel Drive ', '27 mpg', 'Gas', '14.30 gal.', nan, '184.40 in.', '74.50 ', '65.40 in.']
# https://www.carspecs.us/cars/2020/audi/q5
# ['$24,941', nan, nan, '8.44 sec', '211 hp', 'full-time quattro all wheel ', nan, nan, '19.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/audi/q5-hybrid
# ['$60,800', 4, 7, '6.61 sec', '335 hp', 'All Wheel Drive ', '18 mpg', 'Gas', '22.50 gal.', nan, '199.30 in.', '77.60 ', '68.50 in.']
# https://www.carspecs.us/cars/2020/audi/q7
# ['$68,200', 4, 5, nan, '335 hp', 'All Wheel Drive ', '18 mpg', 'Gas', '22.50 gal.', nan, '196.60 in.', '78.50 ', '67.20 in.']
# https://www.carspecs.us/cars/2020/audi/q8
# ['$195,900', 2, 2, nan, '611 hp', 'All Wheel Drive ', '16 mpg', 'Gas', '19.30 gal.', nan, '174.30 in.', '76.40 ', '48.80 in.']
# https://www.carspecs.us/cars/2020/audi/r8
# ['$138,700', 2, 2, '3.69 sec', '532 hp', 'Rear Wheel Drive ', '18 mpg', 'Gas', '21.90 gal.', nan, '174.30 in.', '76.40 ', '48.80 in.']
# https://www.carspecs.us/cars/2018/audi/r8-coupe
# ['$208,100', 2, 2, nan, '610 hp', 'All Wheel Drive ', '17 mpg', 'Gas', '19.30 gal.', nan, '174.30 in.', '76.40 ', '49.00 in.']
# https://www.carspecs.us/cars/2018/audi/r8-spyder
# [nan, 4, 5, '4.46 sec', '400 hp', 'All Wheel Drive ', nan, 'Gas', '14.50 gal.', nan, '176.30 in.', '70.70 ', '55.00 in.']
# https://www.carspecs.us/cars/2019/audi/rs-3
# ['$14,051', 4, 5, nan, '420 hp', 'All Wheel Drive ', nan, 'Gas', '16.60 gal.', nan, '180.70 in.', '71.50 ', '28.20 in.']
# https://www.carspecs.us/cars/2008/audi/rs-4
# ['$48,921', 2, 4, '4.13 sec', '450 hp', 'All Wheel Drive ', '18 mpg', 'Gas', '16.10 gal.', nan, '183.00 in.', '73.20 ', '53.80 in.']
# https://www.carspecs.us/cars/2015/audi/rs-5
# [nan, 2, 4, '4.18 sec', '444 hp', 'All Wheel Drive ', nan, 'Gas', '15.30 gal.', nan, '185.90 in.', '73.30 ', '53.50 in.']
# https://www.carspecs.us/cars/2019/audi/rs-5-coupe
# ['$113,900', 4, 4, '4.10 sec', '560 hp', 'All Wheel Drive ', '17 mpg', 'Gas', '19.80 gal.', nan, '197.30 in.', '75.20 ', '55.80 in.']
# https://www.carspecs.us/cars/2018/audi/rs-7
# ['$113,000', 4, 5, nan, '591 hp', 'All Wheel Drive ', '15 mpg', 'Gas', '22.50 gal.', nan, '197.30 in.', '78.70 ', '66.70 in.']
# https://www.carspecs.us/cars/2020/audi/rs-q8
# [nan, 4, 5, '5.50 sec', '292 hp', 'All Wheel Drive ', nan, 'Gas', '14.50 gal.', nan, '175.80 in.', '70.70 ', '54.80 in.']
# https://www.carspecs.us/cars/2019/audi/s3
# [nan, 4, 5, '5.16 sec', '354 hp', 'All Wheel Drive ', nan, 'Gas', '15.30 gal.', nan, '186.80 in.', '72.50 ', '55.30 in.']
# https://www.carspecs.us/cars/2019/audi/s4
# [nan, nan, nan, nan, '354 hp', ' All wheel drive  ', nan, 'Gas', nan, nan, nan, nan, nan]
# https://www.carspecs.us/cars/2018/audi/s5
# [nan, 2, 4, '5.51 sec', '354 hp', 'All Wheel Drive ', nan, 'Gas', '15.30 gal.', nan, '184.70 in.', '72.70 ', '54.40 in.']
# https://www.carspecs.us/cars/2019/audi/s5-cabriolet
# [nan, 2, 4, '5.14 sec', '354 hp', 'All Wheel Drive ', nan, 'Gas', '15.30 gal.', nan, '184.70 in.', '72.70 ', '53.90 in.']
# https://www.carspecs.us/cars/2019/audi/s5-coupe
# [nan, 4, 5, '5.23 sec', '354 hp', 'All Wheel Drive ', nan, 'Gas', '15.30 gal.', nan, '187.10 in.', '72.60 ', '54.50 in.']
# https://www.carspecs.us/cars/2019/audi/s5-sportback
# ['$71,900', 4, 5, '4.84 sec', '450 hp', 'All Wheel Drive ', '18 mpg', 'Gas', '19.80 gal.', nan, '194.40 in.', '73.80 ', '56.80 in.']
# https://www.carspecs.us/cars/2018/audi/s6
# ['$81,200', 4, 4, '4.83 sec', '450 hp', 'All Wheel Drive ', '18 mpg', 'Gas', '19.80 gal.', nan, '196.30 in.', '75.20 ', '55.00 in.']
# https://www.carspecs.us/cars/2018/audi/s7
# [nan, nan, nan, '3.99 sec', '605 hp', ' All wheel drive  ', nan, 'Gas', '21.70 gal.', nan, '202.60 in.', '76.70 ', '57.40 in.']
# https://www.carspecs.us/cars/2018/audi/s8
# ['$115,900', 4, 5, '3.72 sec', '605 hp', 'All Wheel Drive ', '18 mpg', 'Gas', '21.70 gal.', nan, '202.60 in.', '76.70 ', '57.40 in.']
# https://www.carspecs.us/cars/2018/audi/s8-plus
# [nan, 4, 5, '5.69 sec', '354 hp', 'All Wheel Drive ', '21 mpg', 'Gas', '18.50 gal.', nan, '183.90 in.', '74.50 ', '65.30 in.']
# https://www.carspecs.us/cars/2019/audi/sq5
# ['$84,800', 4, 7, nan, '500 hp', 'All Wheel Drive ', '17 mpg', 'Gas', '22.50 gal.', nan, '199.60 in.', '77.60 ', '68.50 in.']
# https://www.carspecs.us/cars/2020/audi/sq7
# ['$89,000', 4, 5, nan, '500 hp', 'All Wheel Drive ', '17 mpg', 'Gas', '22.50 gal.', nan, '196.60 in.', '78.50 ', '67.20 in.']
# https://www.carspecs.us/cars/2020/audi/sq8
# ['$54,500', 2, 4, '5.26 sec', '292 hp', 'All Wheel Drive ', '25 mpg', 'Gas', '14.50 gal.', nan, '165.00 in.', '72.10 ', '53.30 in.']
# https://www.carspecs.us/cars/2020/audi/tt
# ['$43,950', 2, 4, '6.35 sec', '220 hp', 'All Wheel Drive ', '26 mpg', 'Gas', '14.50 gal.', nan, '164.70 in.', '72.10 ', '53.20 in.']
# https://www.carspecs.us/cars/2018/audi/tt-coupe
# ['$47,450', 2, 2, '6.67 sec', '220 hp', 'All Wheel Drive ', '26 mpg', 'Gas', '14.50 gal.', nan, '164.70 in.', '72.10 ', '53.20 in.']
# https://www.carspecs.us/cars/2018/audi/tt-roadster
# ['$64,900', nan, nan, nan, '400 hp', ' All wheel drive  ', nan, 'Gas', nan, nan, nan, nan, nan]
# https://www.carspecs.us/cars/2018/audi/tt-rs
# ['$52,950', 2, 4, '5.26 sec', '292 hp', 'All Wheel Drive ', '25 mpg', 'Gas', '14.50 gal.', nan, '165.00 in.', '72.10 ', '52.80 in.']
# https://www.carspecs.us/cars/2018/audi/tts
# [nan, nan, nan, '5.57 sec', '500 hp', ' Rear wheel drive  ', nan, 'Gas', '25.30 gal.', '117.00 cu.ft.', '212.60 in.', '74.80 ', '59.70 in.']
# https://www.carspecs.us/cars/2009/bentley/arnage
# ['$105,270', 2, 5, '6.22 sec', '450 hp', 'Rear Wheel Drive ', '11 mpg', 'Gas', '25.40 gal.', nan, '212.60 in.', '74.80 ', '58.50 in.']
# https://www.carspecs.us/cars/2010/bentley/azure
# [nan, nan, nan, '5.75 sec', '500 hp', ' Rear wheel drive  ', nan, 'Gas', '25.30 gal.', nan, '213.00 in.', '74.80 ', '58.70 in.']
# https://www.carspecs.us/cars/2010/bentley/azure-t
# [nan, 4, 5, nan, '429 hp', 'All Wheel Drive ', nan, 'Gas', '22.50 gal.', nan, nan, '78.70 ', '68.60 in.']
# https://www.carspecs.us/cars/2019/bentley/bentayga
# ['$98,887', 2, 4, '5.06 sec', '530 hp', 'Rear Wheel Drive ', '11 mpg', 'Gas', '25.30 gal.', nan, '213.00 in.', '81.80 ', '58.00 in.']
# https://www.carspecs.us/cars/2010/bentley/brooklands
# [nan, nan, nan, '4.88 sec', '500 hp', ' All wheel drive  ', nan, 'Gas', '24.00 gal.', nan, '189.30 in.', '76.70 ', '55.20 in.']
# https://www.carspecs.us/cars/2017/bentley/continental
# ['$116,290', 4, 5, '4.41 sec', '616 hp', 'All Wheel Drive ', nan, 'Gas', '23.80 gal.', nan, '208.50 in.', '77.80 ', '27.90 in.']
# https://www.carspecs.us/cars/2014/bentley/continental-flying-spur
# [nan, nan, nan, '4.57 sec', '600 hp', ' All wheel drive  ', nan, 'Flex Fuel', '23.80 gal.', '118.70 cu.ft.', '208.30 in.', '77.80 ', '54.60 in.']
# https://www.carspecs.us/cars/2013/bentley/continental-flying-spur-speed
# [nan, 2, 4, '3.56 sec', '626 hp', 'All Wheel Drive ', nan, 'Gas', '24.00 gal.', nan, '190.90 in.', '77.40 ', '55.30 in.']
# https://www.carspecs.us/cars/2019/bentley/continental-gt
# ['$177,744', 2, 4, '4.39 sec', '626 hp', 'All Wheel Drive ', '15 mpg', 'Gas', '23.80 gal.', nan, '189.20 in.', '76.50 ', '54.80 in.']
# https://www.carspecs.us/cars/2015/bentley/continental-gt-speed
# ['$115,188', nan, nan, '4.39 sec', '626 hp', ' All wheel drive  ', nan, 'Flex Fuel', '24.00 gal.', '93.00 cu.ft.', '189.20 in.', '76.50 ', '54.80 in.']
# https://www.carspecs.us/cars/2014/bentley/continental-gt-speed-convertible
# ['$146,625', 2, 4, '5.16 sec', '500 hp', 'All Wheel Drive ', '17 mpg', 'Gas', '23.80 gal.', nan, '189.10 in.', '76.50 ', '55.20 in.']
# https://www.carspecs.us/cars/2015/bentley/continental-gt-v8
# ['$155,940', 2, 4, '5.00 sec', '521 hp', 'All Wheel Drive ', '17 mpg', 'Gas', '23.80 gal.', nan, '189.10 in.', '76.50 ', '55.20 in.']
# https://www.carspecs.us/cars/2015/bentley/continental-gt-v8-s
# [nan, nan, nan, '4.27 sec', '572 hp', ' All wheel drive  ', nan, 'Gas', '24.00 gal.', nan, '189.20 in.', '76.50 ', '55.30 in.']
# https://www.carspecs.us/cars/2015/bentley/continental-gt3-r
# ['$113,216', nan, nan, '5.00 sec', '521 hp', ' All wheel drive  ', nan, 'Gas', '24.00 gal.', nan, '189.20 in.', '76.50 ', '55.20 in.']
# https://www.carspecs.us/cars/2014/bentley/continental-gtc
# [nan, nan, nan, '4.52 sec', '600 hp', ' All wheel drive  ', nan, 'Gas', '23.80 gal.', '93.00 cu.ft.', '189.10 in.', '75.50 ', '54.70 in.']
# https://www.carspecs.us/cars/2010/bentley/continental-gtc-speed
# ['$143,031', nan, nan, '3.72 sec', '631 hp', 'automatic full-time all wheel ', nan, nan, '23.80 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bentley/continental-supersports
# ['$112,160', nan, nan, '4.28 sec', '621 hp', ' All wheel drive  ', nan, 'Flex Fuel', '24.00 gal.', '93.00 cu.ft.', '189.10 in.', '76.60 ', '54.30 in.']
# https://www.carspecs.us/cars/2012/bentley/continental-supersports-convertible
# ['$205,000', 4, 5, '4.92 sec', '521 hp', 'All Wheel Drive ', nan, 'Gas', '24.00 gal.', nan, '208.60 in.', '77.80 ', '27.90 in.']
# https://www.carspecs.us/cars/2018/bentley/flying-spur
# ['$361,500', 4, 4, '5.76 sec', '505 hp', 'Rear Wheel Drive ', nan, 'Gas', '25.40 gal.', nan, '229.30 in.', '75.80 ', '60.70 in.']
# https://www.carspecs.us/cars/2019/bentley/mulsanne
# ['$21,192', nan, nan, '4.89 sec', '320 hp', ' Rear wheel drive  ', nan, 'Gas', '14.00 gal.', '96.00 cu.ft.', '172.20 in.', '68.80 ', '56.00 in.']
# https://www.carspecs.us/cars/2013/bmw/1-series
# ['$15,685', 2, 4, '4.64 sec', '335 hp', 'Rear Wheel Drive ', nan, 'Gas', '14.00 gal.', nan, '172.20 in.', '71.00 ', '55.90 in.']
# https://www.carspecs.us/cars/2011/bmw/1-series-m
# ['$23,495', nan, nan, '6.43 sec', '230 hp', 'rear-wheel ', nan, nan, '14.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/128
# ['$23,495', nan, nan, '5.43 sec', '300 hp', 'rear-wheel ', nan, nan, '14.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/135
# ['$21,192', nan, nan, '4.89 sec', '320 hp', ' Rear wheel drive  ', nan, 'Gas', '14.00 gal.', '96.00 cu.ft.', '172.20 in.', '68.80 ', '56.00 in.']
# https://www.carspecs.us/cars/2013/bmw/1-series
# ['$34,800', nan, nan, '6.41 sec', '248 hp', ' Rear wheel drive  ', nan, 'Gas', '13.70 gal.', '99.00 cu.ft.', '174.70 in.', '69.80 ', '55.80 in.']
# https://www.carspecs.us/cars/2018/bmw/2-series
# ['$34,800', nan, nan, '6.41 sec', '248 hp', ' Rear wheel drive  ', nan, 'Gas', '13.70 gal.', '99.00 cu.ft.', '174.70 in.', '69.80 ', '55.80 in.']
# https://www.carspecs.us/cars/2018/bmw/2-series
# ['$36,900', nan, nan, '8.08 sec', '180 hp', ' Rear wheel drive  ', nan, 'Gas', '15.80 gal.', nan, '182.80 in.', '71.30 ', '56.30 in.']
# https://www.carspecs.us/cars/2018/bmw/3-series
# ['$50,900', nan, nan, '6.94 sec', '248 hp', ' All wheel drive  ', nan, 'Gas', '15.80 gal.', '120.40 cu.ft.', '190.00 in.', '72.00 ', '59.40 in.']
# https://www.carspecs.us/cars/2018/bmw/3-series-gran-turismo
# ['$5,536', nan, nan, '6.82 sec', '215 hp', 'xDrive full-time all wheel ', nan, nan, '15.90 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2006/bmw/325
# ['$21,143', nan, nan, '6.65 sec', '240 hp', 'rear-wheel ', nan, nan, '15.80 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/328
# [nan, nan, nan, '5.86 sec', '255 hp', 'rear-wheel ', nan, nan, '15.90 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2006/bmw/330
# ['$22,099', nan, nan, '5.35 sec', '300 hp', 'rear-wheel ', nan, nan, '16.10 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/335
# [nan, nan, nan, '5.84 sec', '265 hp', 'rear-wheel ', nan, nan, '16.10 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2011/bmw/335d
# ['$36,900', nan, nan, '8.08 sec', '180 hp', ' Rear wheel drive  ', nan, 'Gas', '15.80 gal.', nan, '182.80 in.', '71.30 ', '56.30 in.']
# https://www.carspecs.us/cars/2018/bmw/3-series
# [nan, nan, nan, nan, '248 hp', ' Rear wheel drive  ', nan, 'Gas', '15.80 gal.', nan, '182.70 in.', '71.90 ', '54.20 in.']
# https://www.carspecs.us/cars/2018/bmw/4-series
# [nan, nan, nan, '6.79 sec', '248 hp', ' Rear wheel drive  ', nan, 'Gas', '15.80 gal.', nan, '182.70 in.', '71.90 ', '54.70 in.']
# https://www.carspecs.us/cars/2018/bmw/4-series-gran-coupe
# [nan, nan, nan, nan, '248 hp', ' Rear wheel drive  ', nan, 'Gas', '15.80 gal.', nan, '182.70 in.', '71.90 ', '54.20 in.']
# https://www.carspecs.us/cars/2018/bmw/4-series
# [nan, nan, nan, '7.15 sec', '240 hp', ' Rear wheel drive  ', nan, 'Gas', '18.50 gal.', '116.00 cu.ft.', '193.40 in.', '73.20 ', '57.60 in.']
# https://www.carspecs.us/cars/2016/bmw/5-series
# [nan, nan, nan, '6.83 sec', '300 hp', ' Rear wheel drive  ', nan, 'Gas', '18.50 gal.', nan, '197.10 in.', '74.80 ', '61.60 in.']
# https://www.carspecs.us/cars/2017/bmw/5-series-gran-turismo
# [nan, nan, nan, '6.67 sec', '215 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2007/bmw/525
# ['$34,349', nan, nan, '7.10 sec', '240 hp', 'xDrive full-time all wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/528
# [nan, nan, nan, '5.93 sec', '255 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2007/bmw/530
# ['$31,850', nan, nan, '5.91 sec', '300 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/535
# [nan, nan, nan, '6.78 sec', '300 hp', 'xDrive full-time all wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/535-gran-turismo
# [nan, nan, nan, '5.22 sec', '325 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2005/bmw/545
# ['$31,850', nan, nan, '5.02 sec', '400 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/550
# [nan, nan, nan, '5.87 sec', '400 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/550-gran-turismo
# [nan, nan, nan, '7.15 sec', '240 hp', ' Rear wheel drive  ', nan, 'Gas', '18.50 gal.', '116.00 cu.ft.', '193.40 in.', '73.20 ', '57.60 in.']
# https://www.carspecs.us/cars/2016/bmw/5-series
# [nan, nan, nan, '6.32 sec', '315 hp', ' Rear wheel drive  ', nan, 'Gas', '18.50 gal.', '99.00 cu.ft.', '192.80 in.', '74.60 ', '53.70 in.']
# https://www.carspecs.us/cars/2018/bmw/6-series
# [nan, nan, nan, '6.23 sec', '315 hp', ' Rear wheel drive  ', nan, 'Gas', '18.50 gal.', '109.00 cu.ft.', '197.10 in.', '74.60 ', '54.80 in.']
# https://www.carspecs.us/cars/2018/bmw/6-series-gran-coupe
# ['$56,178', nan, nan, '6.33 sec', '315 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/640
# [nan, nan, nan, '6.26 sec', '315 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/640-gran-coupe
# [nan, nan, nan, '5.27 sec', '325 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2005/bmw/645
# [nan, nan, nan, '5.14 sec', '443 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/650
# [nan, nan, nan, '4.92 sec', '443 hp', 'rear-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/650-gran-coupe
# [nan, nan, nan, '6.32 sec', '315 hp', ' Rear wheel drive  ', nan, 'Gas', '18.50 gal.', '99.00 cu.ft.', '192.80 in.', '74.60 ', '53.70 in.']
# https://www.carspecs.us/cars/2018/bmw/6-series
# [nan, nan, nan, '6.19 sec', '320 hp', ' Rear wheel drive  ', nan, 'Gas', '20.60 gal.', nan, '206.60 in.', '74.90 ', '58.20 in.']
# https://www.carspecs.us/cars/2018/bmw/7-series
# ['$66,700', nan, nan, '5.03 sec', '445 hp', ' Rear wheel drive  ', nan, 'Gas', '18.50 gal.', '109.00 cu.ft.', '197.20 in.', '74.60 ', '54.80 in.']
# https://www.carspecs.us/cars/2014/bmw/7-series-gran-coupe
# [nan, nan, nan, '5.73 sec', '315 hp', 'rear-wheel ', nan, nan, '21.70 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/740
# [nan, nan, nan, '6.31 sec', '325 hp', 'rear-wheel ', nan, nan, '23.30 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2005/bmw/745
# ['$64,239', nan, nan, '4.51 sec', '443 hp', 'xDrive full-time all wheel ', nan, nan, '21.70 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/750
# [nan, nan, nan, '4.22 sec', '536 hp', 'rear-wheel ', nan, nan, '21.70 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/760
# [nan, nan, nan, '6.19 sec', '320 hp', ' Rear wheel drive  ', nan, 'Gas', '20.60 gal.', nan, '206.60 in.', '74.90 ', '58.20 in.']
# https://www.carspecs.us/cars/2018/bmw/7-series
# [nan, nan, nan, '6.06 sec', '300 hp', 'rear-wheel ', nan, nan, '15.80 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/activehybrid-3
# [nan, nan, nan, '6.08 sec', '335 hp', ' Rear wheel drive  ', nan, 'Hybrid', '17.70 gal.', '112.00 cu.ft.', '193.40 in.', '73.20 ', '57.60 in.']
# https://www.carspecs.us/cars/2016/bmw/activehybrid-5
# [nan, nan, nan, '6.49 sec', '335 hp', ' Rear wheel drive  ', nan, 'Hybrid', '20.10 gal.', '125.00 cu.ft.', '205.50 in.', '74.90 ', '58.30 in.']
# https://www.carspecs.us/cars/2015/bmw/activehybrid-7
# [nan, nan, nan, '5.97 sec', '315 hp', 'rear-wheel ', nan, nan, '21.70 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/activehybrid-740
# [nan, nan, nan, '4.76 sec', '440 hp', 'rear-wheel ', nan, nan, '21.70 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2012/bmw/activehybrid-750
# [nan, nan, nan, '5.55 sec', '480 hp', ' All wheel drive  ', nan, 'Hybrid', '22.50 gal.', nan, '192.10 in.', '78.10 ', '66.50 in.']
# https://www.carspecs.us/cars/2011/bmw/activehybrid-x6
# ['$124,300', nan, nan, '4.08 sec', '600 hp', ' All wheel drive  ', nan, 'Gas', '18.50 gal.', nan, '197.10 in.', '74.60 ', '55.00 in.']
# https://www.carspecs.us/cars/2018/bmw/alpina-b6-gran-coupe
# [nan, nan, nan, '4.11 sec', '600 hp', ' All wheel drive  ', nan, 'Gas', '20.60 gal.', nan, '206.70 in.', '74.90 ', '58.70 in.']
# https://www.carspecs.us/cars/2018/bmw/alpina-b7
# ['$44,450', 4, 4, '7.68 sec', '170 hp', 'Rear Wheel Drive ', '113 mpg', 'Electric', nan, '84.00 cu.ft.', '158.30 in.', '69.90 ', '62.90 in.']
# https://www.carspecs.us/cars/2020/bmw/i3
# ['$147,500', 2, 4, '4.65 sec', '369 hp', 'All Wheel Drive ', '27 mpg', 'Gas', '11.10 gal.', '81.00 cu.ft.', '184.90 in.', '76.50 ', '50.80 in.']
# https://www.carspecs.us/cars/2020/bmw/i8
# ['$9,018', nan, nan, '4.63 sec', '330 hp', 'rear-wheel ', nan, nan, '14.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2007/bmw/m
# ['$58,900', 2, 4, nan, '405 hp', 'Rear Wheel Drive ', nan, 'Gas', '13.70 gal.', nan, '176.20 in.', '73.00 ', '55.50 in.']
# https://www.carspecs.us/cars/2019/bmw/m2
# ['$66,500', 4, 5, '4.10 sec', '425 hp', 'Rear Wheel Drive ', '20 mpg', 'Gas', '15.90 gal.', nan, '184.50 in.', '73.90 ', '56.10 in.']
# https://www.carspecs.us/cars/2018/bmw/m3
# ['$77,650', 2, 4, '4.54 sec', '425 hp', 'Rear Wheel Drive ', nan, 'Gas', '15.90 gal.', nan, '184.50 in.', '73.60 ', '54.60 in.']
# https://www.carspecs.us/cars/2019/bmw/m4
# ['$102,700', 4, 5, nan, '600 hp', 'All Wheel Drive ', nan, 'Gas', '20.10 gal.', nan, '195.50 in.', '74.90 ', '58.00 in.']
# https://www.carspecs.us/cars/2019/bmw/m5
# ['$119,900', 4, 5, '4.21 sec', '560 hp', 'Rear Wheel Drive ', '16 mpg', 'Gas', '21.10 gal.', nan, '197.50 in.', '74.80 ', '54.90 in.']
# https://www.carspecs.us/cars/2019/bmw/m6
# ['$35,200', 4, 5, nan, '228 hp', 'Front Wheel Drive ', '27 mpg', 'Gas', '16.10 gal.', '101.20 cu.ft.', '175.50 in.', '71.70 ', '62.90 in.']
# https://www.carspecs.us/cars/2020/bmw/x1
# ['$36,400', 4, 5, nan, '228 hp', 'Front Wheel Drive ', '27 mpg', 'Gas', '16.10 gal.', '94.10 cu.ft.', '172.20 in.', '71.80 ', '60.10 in.']
# https://www.carspecs.us/cars/2020/bmw/x2
# ['$69,900', 4, 5, nan, '473 hp', 'All Wheel Drive ', '16 mpg', 'Gas', '17.20 gal.', nan, '186.20 in.', '74.70 ', '65.60 in.']
# https://www.carspecs.us/cars/2020/bmw/x3
# ['$51,100', 4, 5, '7.11 sec', '248 hp', 'All Wheel Drive ', '25 mpg', 'Gas', '17.20 gal.', '97.80 cu.ft.', '187.50 in.', '75.50 ', '63.80 in.']
# https://www.carspecs.us/cars/2020/bmw/x4
# ['$61,200', 4, 5, nan, '335 hp', 'All Wheel Drive ', '22 mpg', 'Gas', '21.90 gal.', nan, '194.30 in.', '78.90 ', '68.70 in.']
# https://www.carspecs.us/cars/2020/bmw/x5
# [nan, nan, nan, '4.57 sec', '567 hp', ' All wheel drive  ', nan, nan, '22.40 gal.', nan, '192.10 in.', '78.10 ', '69.10 in.']
# https://www.carspecs.us/cars/2016/bmw/x5-m
# ['$66,600', 4, 5, nan, '335 hp', 'All Wheel Drive ', '22 mpg', 'Gas', '22.40 gal.', nan, '194.80 in.', '78.90 ', '66.30 in.']
# https://www.carspecs.us/cars/2020/bmw/x6
# [nan, nan, nan, '4.69 sec', '555 hp', 'xDrive full-time all wheel ', nan, nan, '22.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/bmw/x6-m
# ['$73,900', 4, 7, nan, '335 hp', 'All Wheel Drive ', '22 mpg', 'Gas', '21.90 gal.', nan, '203.30 in.', '78.70 ', '71.10 in.']
# https://www.carspecs.us/cars/2020/bmw/x7
# ['$63,700', 2, 2, '4.69 sec', '382 hp', 'Rear Wheel Drive ', '26 mpg', 'Gas', '13.70 gal.', nan, '170.70 in.', '73.40 ', '51.40 in.']
# https://www.carspecs.us/cars/2020/bmw/z4
# [nan, nan, nan, '4.59 sec', '330 hp', 'rear-wheel ', nan, nan, '14.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2008/bmw/z4m
# [nan, nan, nan, '1.88 sec', '1,200 hp', 'full-time all wheel ', nan, nan, '26.40 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2011/bugatti/veyron
# [nan, nan, nan, '2.20 sec', '1,001 hp', ' All wheel drive  ', nan, 'Gas', '26.40 gal.', nan, '175.70 in.', '78.70 ', '45.60 in.']
# https://www.carspecs.us/cars/2009/bugatti/veyron-16-4
# ['$36,070', 2, 4, '9.15 sec', '200 hp', 'Front Wheel Drive ', '24 mpg', 'Gas', '14.30 gal.', '82.00 cu.ft.', '184.90 in.', '72.40 ', '56.80 in.']
# https://www.carspecs.us/cars/2019/buick/cascada
# ['$3,306', 4, 6, '8.88 sec', '175 hp', 'Front Wheel Drive ', nan, 'Gas', '17.00 gal.', nan, '194.60 in.', '72.70 ', '56.60 in.']
# https://www.carspecs.us/cars/2005/buick/century
# ['$56,100', 4, 7, '6.59 sec', '310 hp', 'All Wheel Drive ', '20 mpg', 'Gas', '21.70 gal.', '157.30 cu.ft.', '204.30 in.', '78.80 ', '69.90 in.']
# https://www.carspecs.us/cars/2020/buick/enclave
# ['$30,800', 4, 5, '9.43 sec', '138 hp', 'All Wheel Drive ', '26 mpg', 'Gas', '14.00 gal.', '92.80 cu.ft.', '168.35 in.', '70.10 ', '65.25 in.']
# https://www.carspecs.us/cars/2020/buick/encore
# ['$37,550', 4, 5, '8.12 sec', '197 hp', 'All Wheel Drive ', '24 mpg', 'Gas', '17.30 gal.', '100.60 cu.ft.', '183.70 in.', '72.40 ', '66.80 in.']
# https://www.carspecs.us/cars/2020/buick/envision
# [nan, 4, 5, '5.68 sec', '310 hp', 'All Wheel Drive ', '23 mpg', 'Gas', '15.80 gal.', '102.00 cu.ft.', '197.50 in.', '73.50 ', '57.50 in.']
# https://www.carspecs.us/cars/2018/buick/lacrosse
# [nan, 4, 5, '5.68 sec', '310 hp', 'All Wheel Drive ', '23 mpg', 'Gas', '15.80 gal.', '102.00 cu.ft.', '197.50 in.', '73.50 ', '57.50 in.']
# https://www.carspecs.us/cars/2018/buick/lacrosse
# ['$4,857', 4, 6, '8.32 sec', '205 hp', 'Front Wheel Drive ', nan, 'Gas', '18.00 gal.', nan, '200.00 in.', '73.50 ', '57.00 in.']
# https://www.carspecs.us/cars/2005/buick/lesabre
# ['$15,116', 4, 5, '6.92 sec', '292 hp', 'Front Wheel Drive ', '18 mpg', 'Gas', '18.00 gal.', nan, '203.20 in.', '73.80 ', '58.00 in.']
# https://www.carspecs.us/cars/2011/buick/lucerne
# ['$6,109', 4, 6, '7.84 sec', '240 hp', 'Front Wheel Drive ', nan, 'Gas', '18.00 gal.', nan, '206.80 in.', '74.70 ', '57.40 in.']
# https://www.carspecs.us/cars/2005/buick/park-avenue
# ['$5,679', nan, nan, '6.91 sec', '291 hp', ' Rear wheel drive  ', nan, 'Gas', '22.00 gal.', nan, '193.40 in.', '75.40 ', '74.50 in.']
# https://www.carspecs.us/cars/2007/buick/rainier
# ['$35,770', 4, 5, '7.54 sec', '250 hp', 'Front Wheel Drive ', '26 mpg', 'Gas', '16.30 gal.', nan, '192.90 in.', '73.30 ', '57.30 in.']
# https://www.carspecs.us/cars/2020/buick/regal
# ['$35,270', 4, 5, '7.54 sec', '250 hp', 'Front Wheel Drive ', nan, 'Gas', '16.30 gal.', nan, '192.90 in.', '73.30 ', '57.30 in.']
# https://www.carspecs.us/cars/2019/buick/regal-sportback
# ['$29,070', 4, 5, '6.50 sec', '250 hp', 'All Wheel Drive ', nan, 'Gas', '16.30 gal.', nan, '196.30 in.', '73.30 ', '58.40 in.']
# https://www.carspecs.us/cars/2019/buick/regal-tourx
# ['$4,534', 4, 5, '9.50 sec', '196 hp', 'Front Wheel Drive ', nan, 'Gas', '18.00 gal.', nan, '186.50 in.', '73.60 ', '68.90 in.']
# https://www.carspecs.us/cars/2007/buick/rendezvous
# ['$4,798', 4, 7, '8.71 sec', '240 hp', 'Front Wheel Drive ', nan, 'Gas', '25.00 gal.', nan, '205.00 in.', '75.20 ', '72.00 in.']
# https://www.carspecs.us/cars/2007/buick/terraza
# [nan, 4, 5, '8.61 sec', '180 hp', 'Front Wheel Drive ', '24 mpg', 'Gas', '15.60 gal.', '91.00 cu.ft.', '183.90 in.', '71.40 ', '58.10 in.']
# https://www.carspecs.us/cars/2017/buick/verano
# ['$44,795', 2, 4, '5.74 sec', '272 hp', 'All Wheel Drive ', '24 mpg', 'Gas', '16.00 gal.', '91.00 cu.ft.', '183.60 in.', '72.50 ', '54.80 in.']
# https://www.carspecs.us/cars/2019/cadillac/ats
# ['$41,395', 2, 4, '5.74 sec', '272 hp', 'All Wheel Drive ', nan, 'Gas', '16.00 gal.', nan, '183.60 in.', '72.50 ', '54.80 in.']
# https://www.carspecs.us/cars/2019/cadillac/ats-coupe
# ['$37,495', 4, 5, '5.69 sec', '272 hp', 'All Wheel Drive ', '25 mpg', 'Gas', '16.00 gal.', nan, '182.80 in.', '71.10 ', '55.90 in.']
# https://www.carspecs.us/cars/2018/cadillac/ats-sedan
# [nan, nan, nan, '4.06 sec', '464 hp', ' Rear wheel drive  ', nan, 'Gas', '16.00 gal.', nan, '184.00 in.', '71.30 ', '55.70 in.']
# https://www.carspecs.us/cars/2018/cadillac/ats-v
# ['$67,795', 2, 4, '4.05 sec', '464 hp', 'Rear Wheel Drive ', nan, 'Gas', '16.00 gal.', nan, '184.70 in.', '72.50 ', '54.50 in.']
# https://www.carspecs.us/cars/2019/cadillac/ats-v-coupe
# ['$61,595', 4, 5, '4.06 sec', '464 hp', 'Rear Wheel Drive ', '19 mpg', 'Gas', '16.00 gal.', nan, '184.00 in.', '71.30 ', '55.70 in.']
# https://www.carspecs.us/cars/2018/cadillac/ats-v-sedan
# ['$32,995', 4, 5, '6.71 sec', '237 hp', 'Rear Wheel Drive ', '27 mpg', 'Gas', nan, nan, '187.20 in.', '71.40 ', '56.00 in.']
# https://www.carspecs.us/cars/2020/cadillac/ct4
# ['$36,895', 4, 5, '6.99 sec', '237 hp', 'Rear Wheel Drive ', '26 mpg', 'Gas', '17.00 gal.', nan, '193.80 in.', '74.10 ', '57.20 in.']
# https://www.carspecs.us/cars/2020/cadillac/ct5
# ['$74,495', 4, 5, '6.74 sec', '335 hp', 'All Wheel Drive ', '21 mpg', 'Gas', '19.50 gal.', '110.00 cu.ft.', '205.80 in.', '74.00 ', '58.00 in.']
# https://www.carspecs.us/cars/2020/cadillac/ct6
# ['$54,695', 4, 5, '6.44 sec', '265 hp', 'All Wheel Drive ', '24 mpg', 'Gas', '19.00 gal.', '97.00 cu.ft.', '195.50 in.', '72.20 ', '57.20 in.']
# https://www.carspecs.us/cars/2019/cadillac/cts
# ['$28,997', nan, nan, '5.86 sec', '318 hp', ' All wheel drive  ', nan, 'Gas', '18.00 gal.', '97.10 cu.ft.', '188.50 in.', '74.10 ', '56.00 in.']
# https://www.carspecs.us/cars/2014/cadillac/cts-coupe
# ['$25,575', nan, nan, '6.75 sec', '270 hp', ' All wheel drive  ', nan, 'Gas', '18.00 gal.', '126.00 cu.ft.', '192.00 in.', '72.50 ', '58.00 in.']
# https://www.carspecs.us/cars/2014/cadillac/cts-wagon
# ['$86,995', 4, 5, '3.64 sec', '640 hp', 'Rear Wheel Drive ', nan, 'Gas', '19.00 gal.', nan, '197.60 in.', '72.20 ', '57.20 in.']
# https://www.carspecs.us/cars/2019/cadillac/cts-v
# ['$48,231', nan, nan, '3.82 sec', '556 hp', ' Rear wheel drive  ', nan, 'Gas', '18.00 gal.', '97.10 cu.ft.', '188.50 in.', '74.10 ', '56.00 in.']
# https://www.carspecs.us/cars/2015/cadillac/cts-v-coupe
# [nan, nan, nan, '3.94 sec', '556 hp', ' Rear wheel drive  ', nan, 'Gas', '18.00 gal.', '126.00 cu.ft.', '192.00 in.', '72.50 ', '58.00 in.']
# https://www.carspecs.us/cars/2014/cadillac/cts-v-wagon
# ['$7,740', 4, 5, '7.02 sec', '290 hp', 'Front Wheel Drive ', nan, 'Gas', '18.00 gal.', nan, '207.20 in.', '74.50 ', '56.70 in.']
# https://www.carspecs.us/cars/2005/cadillac/deville
# ['$17,654', 4, 5, '7.25 sec', '275 hp', 'Front Wheel Drive ', '18 mpg', 'Gas', '18.00 gal.', nan, '207.60 in.', '74.80 ', '57.60 in.']
# https://www.carspecs.us/cars/2011/cadillac/dts
# ['$52,650', 2, 4, nan, '233 hp', 'Front Wheel Drive ', '32 mpg', 'Gas', '9.30 gal.', nan, '186.00 in.', '72.70 ', '55.90 in.']
# https://www.carspecs.us/cars/2016/cadillac/elr
# ['$75,195', 4, 7, nan, '420 hp', 'Rear Wheel Drive ', '17 mpg', 'Gas', '26.00 gal.', nan, '203.90 in.', '80.50 ', '74.40 in.']
# https://www.carspecs.us/cars/2020/cadillac/escalade
# ['$83,795', 4, 7, nan, '420 hp', 'Rear Wheel Drive ', nan, 'Gas', '31.00 gal.', nan, nan, '80.50 ', '74.00 in.']
# https://www.carspecs.us/cars/2019/cadillac/escalade-esv
# ['$30,899', 4, 5, nan, '403 hp', 'All Wheel Drive ', '14 mpg', 'Gas', '31.00 gal.', nan, nan, '79.10 ', '74.50 in.']
# https://www.carspecs.us/cars/2013/cadillac/escalade-ext
# ['$36,468', nan, nan, '7.76 sec', '332 hp', ' Rear wheel drive  ', nan, 'Hybrid', '25.00 gal.', nan, '202.50 in.', '79.00 ', '75.90 in.']
# https://www.carspecs.us/cars/2013/cadillac/escalade-hybrid
# ['$39,625', 4, 5, nan, '308 hp', 'Front Wheel Drive ', '19 mpg', 'Gas', '21.00 gal.', nan, '190.30 in.', '75.20 ', '30.10 in.']
# https://www.carspecs.us/cars/2016/cadillac/srx
# ['$16,075', nan, nan, '6.20 sec', '302 hp', ' Rear wheel drive  ', nan, nan, '17.00 gal.', '116.70 cu.ft.', '196.70 in.', '72.60 ', '57.60 in.']
# https://www.carspecs.us/cars/2011/cadillac/sts
# ['$20,448', 4, 5, '4.81 sec', '469 hp', 'Rear Wheel Drive ', '15 mpg', 'Gas', '17.00 gal.', nan, '197.60 in.', '72.60 ', '58.20 in.']
# https://www.carspecs.us/cars/2009/cadillac/sts-v
# ['$21,553', 2, 2, '5.57 sec', '320 hp', 'Rear Wheel Drive ', '18 mpg', 'Gas', '18.00 gal.', nan, '177.70 in.', '72.30 ', '50.40 in.']
# https://www.carspecs.us/cars/2009/cadillac/xlr
# ['$26,053', 2, 2, '4.51 sec', '443 hp', 'Rear Wheel Drive ', '17 mpg', 'Gas', '18.00 gal.', nan, '177.70 in.', '72.30 ', '50.40 in.']
# https://www.carspecs.us/cars/2009/cadillac/xlr-v
# ['$42,295', 4, 5, '7.00 sec', '237 hp', 'All Wheel Drive ', '24 mpg', 'Gas', '16.30 gal.', '100.60 cu.ft.', '181.10 in.', '76.70 ', '64.10 in.']
# https://www.carspecs.us/cars/2020/cadillac/xt4
# ['$44,095', 4, 5, '7.96 sec', '237 hp', 'Front Wheel Drive ', '24 mpg', 'Gas', '19.40 gal.', '104.50 cu.ft.', '189.60 in.', '74.90 ', '66.10 in.']
# https://www.carspecs.us/cars/2020/cadillac/xt5
# ['$49,095', 4, 5, '6.14 sec', '310 hp', 'All Wheel Drive ', '21 mpg', 'Gas', '21.70 gal.', nan, '189.50 in.', '75.00 ', '66.00 in.']
# https://www.carspecs.us/cars/2018/cadillac/xt5-crossover
# ['$54,695', 4, 7, '6.55 sec', '310 hp', 'All Wheel Drive ', '20 mpg', 'Gas', '22.00 gal.', nan, '198.50 in.', '77.30 ', '69.90 in.']
# https://www.carspecs.us/cars/2020/cadillac/xt6
# ['$50,595', 4, 5, '6.75 sec', '304 hp', 'Front Wheel Drive ', nan, 'Gas', '19.00 gal.', '104.20 cu.ft.', '200.90 in.', '72.91 ', '59.40 in.']
# https://www.carspecs.us/cars/2019/cadillac/xts
# [nan, nan, nan, '9.38 sec', '190 hp', 'automatic full-time all wheel ', nan, nan, '27.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2005/chevrolet/astro
# [nan, nan, nan, '8.75 sec', '190 hp', ' Rear wheel drive  ', nan, 'Gas', '27.00 gal.', nan, '189.80 in.', '77.50 ', '75.00 in.']
# https://www.carspecs.us/cars/2005/chevrolet/astro-cargo
# ['$3,964', 3, 8, nan, '190 hp', 'All Wheel Drive ', nan, 'Gas', '27.00 gal.', nan, '61.70 in.', '51.60 in.', '75.00 in.']
# https://www.carspecs.us/cars/2005/chevrolet/astro-passenger
# ['$17,630', 4, 5, nan, '320 hp', 'Rear Wheel Drive ', '17 mpg', 'Gas', '31.50 gal.', nan, nan, '50.00 in.', '76.60 in.']
# https://www.carspecs.us/cars/2013/chevrolet/avalanche
# [nan, nan, nan, '7.64 sec', '320 hp', 'rear-wheel ', nan, nan, '31.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2008/chevrolet/avalanche-1500
# ['$5,905', nan, nan, '8.16 sec', '325 hp', 'AutoTrac automatic full-time four-wheel ', nan, nan, '37.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2006/chevrolet/avalanche-2500
# ['$4,068', 4, 5, '9.74 sec', '108 hp', 'Front Wheel Drive ', '30 mpg', 'Gas', '12.00 gal.', nan, '169.70 in.', '67.30 ', '59.30 in.']
# https://www.carspecs.us/cars/2011/chevrolet/aveo
# ['$2,524', nan, nan, '9.42 sec', '103 hp', 'front-wheel ', nan, nan, '11.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2008/chevrolet/aveo-5
# ['$28,800', 4, 5, '9.05 sec', '193 hp', 'Front Wheel Drive ', '23 mpg', 'Gas', '19.40 gal.', '107.80 cu.ft.', '191.40 in.', '76.70 ', '67.00 in.']
# https://www.carspecs.us/cars/2020/chevrolet/blazer
# ['$36,620', 4, 5, nan, '200 hp', 'Front Wheel Drive ', '118 mpg', 'Electric', nan, '94.40 cu.ft.', '164.00 in.', '69.50 ', '62.80 in.']
# https://www.carspecs.us/cars/2020/chevrolet/bolt-ev
# ['$25,000', 2, 4, '5.45 sec', '275 hp', 'Rear Wheel Drive ', '23 mpg', 'Gas', '19.00 gal.', '93.00 cu.ft.', '188.30 in.', '74.70 ', '53.10 in.']
# https://www.carspecs.us/cars/2020/chevrolet/camaro
# ['$20,358', nan, nan, '9.60 sec', '180 hp', ' Front wheel drive  ', nan, 'Flex Fuel', '19.00 gal.', '126.90 cu.ft.', '180.10 in.', '72.80 ', '67.00 in.']
# https://www.carspecs.us/cars/2015/chevrolet/captiva-sport
# ['$2,191', 4, 5, '8.27 sec', '140 hp', 'Front Wheel Drive ', nan, 'Gas', '14.00 gal.', nan, '180.90 in.', '67.90 ', '26.20 in.']
# https://www.carspecs.us/cars/2005/chevrolet/cavalier
# [nan, nan, nan, '10.83 sec', '131 hp', ' Front wheel drive  ', nan, 'Gas', '14.50 gal.', '178.30 cu.ft.', '186.30 in.', '68.10 ', '73.70 in.']
# https://www.carspecs.us/cars/2017/chevrolet/city-express
# ['$22,855', 4, 2, nan, '131 hp', 'Front Wheel Drive ', '25 mpg', 'Gas', '14.50 gal.', nan, '82.80 in.', '48.00 in.', '73.70 in.']
# https://www.carspecs.us/cars/2018/chevrolet/city-express-cargo-van
# ['$2,925', nan, nan, '9.93 sec', '140 hp', ' Front wheel drive  ', nan, 'Gas', '14.00 gal.', '115.00 cu.ft.', '190.40 in.', '69.40 ', '56.40 in.']
# https://www.carspecs.us/cars/2005/chevrolet/classic
# ['$4,544', 2, 5, '7.76 sec', '155 hp', 'Front Wheel Drive ', '30 mpg', 'Gas', '13.00 gal.', nan, '180.50 in.', '67.90 ', '55.50 in.']
# https://www.carspecs.us/cars/2010/chevrolet/cobalt
# ['$27,700', 2, 4, nan, '200 hp', 'Rear Wheel Drive ', '22 mpg', 'Gas', '21.00 gal.', nan, '212.70 in.', '44.40 in.', '70.40 in.']
# https://www.carspecs.us/cars/2020/chevrolet/colorado
# ['$58,900', 2, 2, '3.35 sec', '490 hp', 'Rear Wheel Drive ', '19 mpg', 'Gas', '18.50 gal.', nan, '182.30 in.', '76.10 ', '48.60 in.']
# https://www.carspecs.us/cars/2020/chevrolet/corvette
# ['$33,060', nan, nan, '3.69 sec', '455 hp', ' Rear wheel drive  ', nan, 'Gas', '18.50 gal.', nan, '176.90 in.', '73.90 ', '48.80 in.']
# https://www.carspecs.us/cars/2014/chevrolet/corvette-stingray
# ['$26,120', 4, 5, '10.40 sec', '137 hp', 'Front Wheel Drive ', '35 mpg', 'Gas', '13.50 gal.', '94.00 cu.ft.', '175.30 in.', '70.50 ', '57.70 in.']
# https://www.carspecs.us/cars/2019/chevrolet/cruze
# [nan, nan, nan, '9.30 sec', '138 hp', ' Front wheel drive  ', nan, 'Gas', '15.60 gal.', '109.60 cu.ft.', '181.00 in.', '70.70 ', '58.10 in.']
# https://www.carspecs.us/cars/2016/chevrolet/cruze-limited
# ['$27,900', 4, 5, '8.25 sec', '170 hp', 'All Wheel Drive ', '27 mpg', 'Gas', '15.60 gal.', '103.50 cu.ft.', '183.10 in.', '72.60 ', '65.40 in.']
# https://www.carspecs.us/cars/2020/chevrolet/equinox
# [nan, nan, nan, '8.94 sec', '285 hp', ' Rear wheel drive  ', nan, 'Flex Fuel', '31.00 gal.', nan, '224.10 in.', '79.20 ', '83.90 in.']
# https://www.carspecs.us/cars/2017/chevrolet/express
# ['$15,937', nan, nan, '7.66 sec', '310 hp', 'automatic full-time all wheel ', nan, nan, '31.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/chevrolet/express-1500
# [nan, nan, nan, '8.60 sec', '260 hp', 'rear-wheel ', nan, nan, '31.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/chevrolet/express-2500
# [nan, nan, nan, '8.45 sec', '280 hp', 'rear-wheel ', nan, nan, '31.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/chevrolet/express-3500
# [nan, nan, nan, '8.09 sec', '285 hp', ' Rear wheel drive  ', nan, 'Flex Fuel', '31.00 gal.', nan, '224.10 in.', '79.20 ', '84.60 in.']
# https://www.carspecs.us/cars/2017/chevrolet/express-cargo
# ['$34,900', 3, 12, nan, '276 hp', 'Rear Wheel Drive ', nan, 'Gas', '31.00 gal.', nan, '89.13 in.', '50.40 in.', '83.90 in.']
# https://www.carspecs.us/cars/2019/chevrolet/express-passenger
# ['$6,470', 2, 2, '8.67 sec', '155 hp', 'Front Wheel Drive ', '26 mpg', 'Gas', '16.20 gal.', nan, '176.20 in.', '69.10 ', '63.10 in.']
# https://www.carspecs.us/cars/2011/chevrolet/hhr
# ['$6,470', nan, nan, '8.67 sec', '155 hp', 'front-wheel ', nan, nan, '16.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2011/chevrolet/hhr-panel
# ['$31,620', 4, 5, nan, '305 hp', 'Front Wheel Drive ', '22 mpg', 'Gas', '18.50 gal.', '105.00 cu.ft.', '201.30 in.', '73.00 ', '58.90 in.']
# https://www.carspecs.us/cars/2020/chevrolet/impala
# ['$22,140', 4, 5, nan, '160 hp', 'Front Wheel Drive ', '32 mpg', 'Gas', '15.80 gal.', '102.90 cu.ft.', '194.20 in.', '73.00 ', '57.90 in.']
# https://www.carspecs.us/cars/2020/chevrolet/malibu
# ['$4,267', 4, 5, '7.43 sec', '219 hp', 'Front Wheel Drive ', nan, 'Gas', '16.00 gal.', nan, '188.30 in.', '69.90 ', '57.50 in.']
# https://www.carspecs.us/cars/2008/chevrolet/malibu-classic
# [nan, nan, nan, nan, '164 hp', ' Front wheel drive  ', nan, 'Hybrid', '16.00 gal.', nan, '191.80 in.', '70.30 ', '57.10 in.']
# https://www.carspecs.us/cars/2009/chevrolet/malibu-hybrid
# ['$18,277', 4, 5, nan, nan, 'Front Wheel Drive ', '27 mpg', 'Gas', '15.80 gal.', nan, '191.50 in.', '73.00 ', '57.60 in.']
# https://www.carspecs.us/cars/2016/chevrolet/malibu-limited
# ['$3,754', 4, 5, '8.24 sec', '201 hp', 'Front Wheel Drive ', nan, 'Gas', '16.00 gal.', '106.00 cu.ft.', '187.80 in.', '69.80 ', '58.10 in.']
# https://www.carspecs.us/cars/2006/chevrolet/malibu-maxx
# ['$3,754', 4, 5, '8.24 sec', '201 hp', 'Front Wheel Drive ', nan, 'Gas', '16.00 gal.', '106.00 cu.ft.', '187.80 in.', '69.80 ', '58.10 in.']
# https://www.carspecs.us/cars/2006/chevrolet/malibu-maxx
# ['$3,782', 2, 5, '7.74 sec', '211 hp', 'Front Wheel Drive ', nan, 'Gas', '17.00 gal.', nan, '196.70 in.', '72.90 ', '55.80 in.']
# https://www.carspecs.us/cars/2007/chevrolet/monte-carlo
# ['$34,600', 4, 6, nan, '285 hp', 'Rear Wheel Drive ', '17 mpg', 'Gas', '24.00 gal.', nan, '231.70 in.', '50.63 in.', '75.60 in.']
# https://www.carspecs.us/cars/2020/chevrolet/silverado-1500
# ['$4,803', 2, 3, nan, '285 hp', 'Four Wheel Drive ', nan, 'Gas', '26.00 gal.', nan, nan, '50.00 in.', '73.80 in.']
# https://www.carspecs.us/cars/2007/chevrolet/silverado-1500-classic
# ['$4,672', 2, 6, nan, '295 hp', 'Rear Wheel Drive ', nan, 'Gas', '26.00 gal.', nan, nan, '50.00 in.', '71.20 in.']
# https://www.carspecs.us/cars/2007/chevrolet/silverado-1500-classic-hybrid
# ['$21,907', 4, 6, nan, '332 hp', 'Four Wheel Drive ', '21 mpg', 'Gas', '26.00 gal.', nan, nan, '50.60 in.', '73.70 in.']
# https://www.carspecs.us/cars/2013/chevrolet/silverado-1500-hybrid
# [nan, nan, nan, '7.54 sec', '295 hp', 'rear-wheel ', nan, nan, '26.00 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2007/chevrolet/silverado-1500-hybrid-classic
# ...
# ['$5,762', 2, 4, '8.21 sec', '210 hp', 'Front Wheel Drive ', nan, 'Gas', '18.50 gal.', nan, '192.50 in.', '71.50 ', '56.50 in.']
# https://www.carspecs.us/cars/2008/toyota/camry-solara
# ['$3,455', 2, 4, '7.16 sec', '180 hp', 'Front Wheel Drive ', nan, 'Gas', '14.50 gal.', nan, '170.50 in.', '68.30 ', '51.40 in.']
# https://www.carspecs.us/cars/2005/toyota/celica
# ['$21,295', 4, 5, nan, '144 hp', 'Front Wheel Drive ', '29 mpg', 'Gas', '13.20 gal.', '86.00 cu.ft.', '172.60 in.', '70.70 ', '61.60 in.']
# https://www.carspecs.us/cars/2020/toyota/c-hr
# ['$23,100', 4, 5, nan, '121 hp', 'Front Wheel Drive ', '52 mpg', 'Gas', '13.20 gal.', '88.60 cu.ft.', '182.30 in.', '70.10 ', '56.50 in.']
# https://www.carspecs.us/cars/2020/toyota/corolla
# ['$21,090', 4, 5, nan, '168 hp', 'Front Wheel Drive ', '36 mpg', 'Gas', '13.20 gal.', nan, '169.90 in.', '69.90 ', '57.10 in.']
# https://www.carspecs.us/cars/2019/toyota/corolla-hatchback
# ['$19,590', 4, 5, '9.91 sec', '137 hp', 'Front Wheel Drive ', '31 mpg', 'Gas', '14.00 gal.', nan, '170.50 in.', '69.30 ', '55.30 in.']
# https://www.carspecs.us/cars/2018/toyota/corolla-im
# ['$1,767', 4, 5, '9.01 sec', '108 hp', 'Front Wheel Drive ', nan, 'Gas', '11.90 gal.', nan, '164.80 in.', '65.40 ', '27.20 in.']
# https://www.carspecs.us/cars/2005/toyota/echo
# ['$16,738', 4, 5, nan, '260 hp', 'Four Wheel Drive ', '16 mpg', 'Gas', '19.00 gal.', nan, '183.90 in.', '75.00 ', '72.00 in.']
# https://www.carspecs.us/cars/2014/toyota/fj-cruiser
# ['$36,800', 4, 8, '7.05 sec', '295 hp', 'Front Wheel Drive ', '23 mpg', 'Gas', '17.90 gal.', '141.30 cu.ft.', '194.90 in.', '76.00 ', '68.10 in.']
# https://www.carspecs.us/cars/2020/toyota/highlander
# ['$43,140', nan, nan, nan, nan, ' All wheel drive  ', nan, 'Hybrid', '17.20 gal.', '158.70 cu.ft.', '192.50 in.', '75.80 ', '68.10 in.']
# https://www.carspecs.us/cars/2017/toyota/highlander-hybrid
# ['$85,415', 4, 8, nan, '381 hp', 'Four Wheel Drive ', '14 mpg', 'Gas', '24.60 gal.', nan, '194.90 in.', '78.00 ', '74.00 in.']
# https://www.carspecs.us/cars/2020/toyota/land-cruiser
# ['$9,856', 4, 5, '9.83 sec', '132 hp', 'Front Wheel Drive ', '28 mpg', 'Gas', '13.20 gal.', nan, '171.90 in.', '69.50 ', '61.00 in.']
# https://www.carspecs.us/cars/2013/toyota/matrix
# ['$58,550', 4, 4, '10.02 sec', '151 hp', 'Front Wheel Drive ', nan, 'Electric', '32.30 gal.', '85.70 cu.ft.', '192.50 in.', '71.50 ', '60.50 in.']
# https://www.carspecs.us/cars/2020/toyota/mirai
# ['$3,921', 2, 2, '6.70 sec', '138 hp', 'Rear Wheel Drive ', nan, 'Gas', '12.70 gal.', nan, '153.00 in.', '66.70 ', '48.80 in.']
# https://www.carspecs.us/cars/2005/toyota/mr2-spyder
# ['$24,325', 4, 5, nan, '121 hp', 'Front Wheel Drive ', '56 mpg', 'Gas', '11.30 gal.', '93.10 cu.ft.', '180.00 in.', '69.30 ', '57.90 in.']
# https://www.carspecs.us/cars/2020/toyota/prius
# [nan, 4, 5, nan, '99 hp', 'Front Wheel Drive ', '46 mpg', 'Gas', '9.50 gal.', '87.40 cu.ft.', '159.80 in.', '67.50 ', '58.70 in.']
# https://www.carspecs.us/cars/2018/toyota/prius-c
# [nan, 4, 5, nan, '99 hp', 'Front Wheel Drive ', '46 mpg', 'Gas', '9.50 gal.', '87.40 cu.ft.', '159.80 in.', '67.50 ', '58.70 in.']
# https://www.carspecs.us/cars/2018/toyota/prius-c
# ['$20,693', nan, nan, '10.48 sec', '134 hp', ' Front wheel drive  ', nan, 'Hybrid', '10.60 gal.', '115.30 cu.ft.', '176.40 in.', '68.70 ', '58.70 in.']
# https://www.carspecs.us/cars/2015/toyota/prius-plug-in
# [nan, nan, nan, '11.77 sec', '121 hp', ' Front wheel drive  ', nan, 'Hybrid', '11.30 gal.', '111.30 cu.ft.', '182.90 in.', '69.30 ', '57.90 in.']
# https://www.carspecs.us/cars/2017/toyota/prius-prime
# [nan, 4, 5, nan, '134 hp', 'Front Wheel Drive ', '41 mpg', 'Gas', '11.90 gal.', '97.20 cu.ft.', '182.90 in.', '69.90 ', '62.00 in.']
# https://www.carspecs.us/cars/2017/toyota/prius-v
# ['$25,950', 4, 5, '7.99 sec', '203 hp', 'Front Wheel Drive ', '30 mpg', 'Gas', '14.50 gal.', '98.90 cu.ft.', '180.90 in.', '73.00 ', '67.00 in.']
# https://www.carspecs.us/cars/2020/toyota/rav4
# ['$28,884', 4, 5, '9.80 sec', '154 hp', 'Front Wheel Drive ', '76 mpg', 'Electric', nan, nan, '180.10 in.', '71.50 ', '66.30 in.']
# https://www.carspecs.us/cars/2014/toyota/rav4-ev
# [nan, nan, nan, '8.21 sec', '194 hp', ' All wheel drive  ', nan, 'Hybrid', '14.80 gal.', '136.30 cu.ft.', '183.50 in.', '72.60 ', '67.10 in.']
# https://www.carspecs.us/cars/2018/toyota/rav4-hybrid
# ['$49,980', 4, 8, nan, '381 hp', 'Rear Wheel Drive ', '15 mpg', 'Gas', '26.40 gal.', nan, '205.10 in.', '79.90 ', '77.00 in.']
# https://www.carspecs.us/cars/2020/toyota/sequoia
# ['$48,055', 4, 7, '7.62 sec', '296 hp', 'Front Wheel Drive ', '21 mpg', 'Gas', '20.00 gal.', '164.40 cu.ft.', '200.60 in.', '78.10 ', '70.70 in.']
# https://www.carspecs.us/cars/2020/toyota/sienna
# ['$49,990', 2, 2, '5.10 sec', '335 hp', 'Rear Wheel Drive ', '26 mpg', 'Gas', '13.70 gal.', '50.90 cu.ft.', '172.50 in.', '73.00 ', '50.90 in.']
# https://www.carspecs.us/cars/2020/toyota/supra
# ['$26,050', 4, 4, nan, '159 hp', 'Rear Wheel Drive ', '21 mpg', 'Gas', '21.10 gal.', nan, '212.30 in.', '41.50 in.', '70.60 in.']
# https://www.carspecs.us/cars/2020/toyota/tacoma
# ['$33,575', 4, 6, nan, '381 hp', 'Rear Wheel Drive ', '15 mpg', 'Gas', '26.40 gal.', nan, '228.90 in.', '50.00 in.', '76.00 in.']
# https://www.carspecs.us/cars/2020/toyota/tundra
# ['$47,380', 4, 5, nan, '381 hp', 'Rear Wheel Drive ', nan, 'Gas', '38.00 gal.', nan, nan, '50.00 in.', '75.80 in.']
# https://www.carspecs.us/cars/2019/toyota/tundra-2wd
# ['$24,564', 4, 5, '5.78 sec', '268 hp', 'All Wheel Drive ', '21 mpg', 'Gas', '17.70 gal.', nan, '189.00 in.', '75.00 ', '28.00 in.']
# https://www.carspecs.us/cars/2015/toyota/venza
# ['$15,650', 4, 5, '9.35 sec', '106 hp', 'Front Wheel Drive ', '34 mpg', 'Gas', '11.60 gal.', '85.90 cu.ft.', '171.20 in.', '66.70 ', '58.50 in.']
# https://www.carspecs.us/cars/2020/toyota/yaris
# ['$17,050', 4, 5, '10.14 sec', '106 hp', 'Front Wheel Drive ', '35 mpg', 'Gas', '11.60 gal.', nan, '171.70 in.', '66.70 ', '58.50 in.']
# https://www.carspecs.us/cars/2018/toyota/yaris-ia
# ['$16,550', 4, 5, nan, '106 hp', 'Front Wheel Drive ', nan, 'Gas', '11.60 gal.', nan, nan, '5.50 in.', nan]
# https://www.carspecs.us/cars/2019/toyota/yaris-sedan
# ['$37,895', 4, 5, '6.35 sec', '268 hp', 'All Wheel Drive ', '23 mpg', 'Gas', '17.40 gal.', '96.20 cu.ft.', '191.40 in.', '73.70 ', '56.50 in.']
# https://www.carspecs.us/cars/2020/volkswagen/arteon
# ['$36,095', 4, 7, '7.67 sec', '276 hp', 'Front Wheel Drive ', '19 mpg', 'Gas', '18.60 gal.', '153.70 cu.ft.', '198.30 in.', '78.30 ', '70.00 in.']
# https://www.carspecs.us/cars/2020/volkswagen/atlas
# ['$23,045', 2, 4, '8.31 sec', '174 hp', 'Front Wheel Drive ', '29 mpg', 'Gas', '14.50 gal.', '85.10 cu.ft.', '168.80 in.', '71.90 ', '58.60 in.']
# https://www.carspecs.us/cars/2019/volkswagen/beetle
# ['$26,840', 2, 4, '8.67 sec', '174 hp', 'Front Wheel Drive ', '29 mpg', 'Gas', '14.50 gal.', nan, '168.80 in.', '71.90 ', '58.00 in.']
# https://www.carspecs.us/cars/2018/volkswagen/beetle-convertible
# ['$16,357', 2, 4, '8.39 sec', '170 hp', 'Front Wheel Drive ', '28 mpg', 'Gas', '14.50 gal.', nan, '168.40 in.', '71.20 ', '58.50 in.']
# https://www.carspecs.us/cars/2016/volkswagen/beetle-coupe
# [nan, nan, nan, '7.06 sec', '200 hp', ' Front wheel drive  ', nan, 'Gas', '18.50 gal.', '109.30 cu.ft.', '188.90 in.', '73.00 ', '55.80 in.']
# https://www.carspecs.us/cars/2017/volkswagen/cc
# ['$31,895', 4, 5, '11.12 sec', '134 hp', 'Front Wheel Drive ', '119 mpg', 'Electric', nan, '93.50 cu.ft.', '168.10 in.', '70.80 ', '57.20 in.']
# https://www.carspecs.us/cars/2019/volkswagen/e-golf
# ['$25,915', 2, 4, '7.31 sec', '200 hp', 'Front Wheel Drive ', '25 mpg', 'Gas', '14.50 gal.', nan, '174.10 in.', '70.50 ', '56.90 in.']
# https://www.carspecs.us/cars/2016/volkswagen/eos
# ['$13,374', 4, 5, '6.76 sec', '200 hp', 'Front Wheel Drive ', nan, 'Gas', '14.50 gal.', nan, '182.20 in.', '70.00 ', '57.20 in.']
# https://www.carspecs.us/cars/2013/volkswagen/gli
# ['$23,195', 4, 5, '8.61 sec', '147 hp', 'Front Wheel Drive ', '31 mpg', 'Gas', '13.20 gal.', '93.50 cu.ft.', '167.60 in.', '70.80 ', '58.20 in.']
# https://www.carspecs.us/cars/2020/volkswagen/golf
# ['$27,055', 4, 5, '7.14 sec', '170 hp', 'All Wheel Drive ', '25 mpg', 'Gas', '14.50 gal.', nan, '180.20 in.', '70.80 ', '59.60 in.']
# https://www.carspecs.us/cars/2018/volkswagen/golf-alltrack
# [nan, nan, nan, '8.12 sec', '180 hp', ' Front wheel drive  ', nan, 'Gas', '14.50 gal.', '88.00 cu.ft.', '164.90 in.', '68.30 ', '56.70 in.']
# https://www.carspecs.us/cars/2017/volkswagen/golf-gti
# ['$40,885', 4, 5, '4.73 sec', '292 hp', 'All Wheel Drive ', '25 mpg', 'Gas', '14.50 gal.', nan, '168.40 in.', '70.80 ', '56.50 in.']
# https://www.carspecs.us/cars/2018/volkswagen/golf-r
# [nan, nan, nan, '8.56 sec', '150 hp', ' Front wheel drive  ', nan, 'Diesel', '13.20 gal.', '124.70 cu.ft.', '179.60 in.', '70.80 ', '58.30 in.']
# https://www.carspecs.us/cars/2017/volkswagen/golf-sportwagen
# ['$12,414', nan, nan, '6.95 sec', '200 hp', 'front-wheel ', nan, nan, '14.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/volkswagen/gti
# ['$26,245', 4, 5, '6.59 sec', '228 hp', 'Front Wheel Drive ', '28 mpg', 'Gas', '13.20 gal.', '94.70 cu.ft.', '185.20 in.', '70.80 ', '56.80 in.']
# https://www.carspecs.us/cars/2020/volkswagen/jetta
# ['$10,437', nan, nan, '6.52 sec', '210 hp', ' Front wheel drive  ', nan, 'Gas', '14.50 gal.', '109.60 cu.ft.', '182.20 in.', '70.00 ', '56.60 in.']
# https://www.carspecs.us/cars/2014/volkswagen/jetta-gli
# [nan, nan, nan, '7.91 sec', '170 hp', 'Front wheel drive ', nan, nan, '11.90 gal.', '105.40 cu.ft.', '182.80 in.', '70.00 ', '57.20 in.']
# https://www.carspecs.us/cars/2014/volkswagen/jetta-hybrid
# ['$16,017', 4, 5, '9.25 sec', '150 hp', 'Front Wheel Drive ', '32 mpg', 'Gas', '14.50 gal.', nan, '183.30 in.', '70.00 ', '57.20 in.']
# https://www.carspecs.us/cars/2016/volkswagen/jetta-sedan
# ['$12,815', nan, nan, '8.15 sec', '170 hp', ' Front wheel drive  ', nan, 'Gas', '14.50 gal.', '124.50 cu.ft.', '179.40 in.', '70.10 ', '59.20 in.']
# https://www.carspecs.us/cars/2014/volkswagen/jetta-sportwagen
# ['$7,653', nan, nan, '9.11 sec', '150 hp', ' Front wheel drive  ', nan, 'Gas', '14.50 gal.', '93.00 cu.ft.', '161.10 in.', '67.90 ', '59.00 in.']
# https://www.carspecs.us/cars/2010/volkswagen/new-beetle
# ['$7,943', 2, 4, '9.75 sec', '150 hp', 'Front Wheel Drive ', '23 mpg', 'Gas', '14.50 gal.', nan, '161.10 in.', '67.90 ', '59.10 in.']
# https://www.carspecs.us/cars/2010/volkswagen/new-beetle-convertible
# ['$22,995', 4, 5, '8.88 sec', '174 hp', 'Front Wheel Drive ', '27 mpg', 'Gas', '18.50 gal.', '102.00 cu.ft.', '193.60 in.', '72.20 ', '58.00 in.']
# https://www.carspecs.us/cars/2020/volkswagen/passat
# ['$7,886', 4, 5, '7.04 sec', '200 hp', 'Front Wheel Drive ', '25 mpg', 'Gas', '18.50 gal.', nan, '188.20 in.', '71.70 ', '58.00 in.']
# https://www.carspecs.us/cars/2010/volkswagen/passat-sedan
# ['$10,672', nan, nan, '6.72 sec', '335 hp', ' All wheel drive  ', nan, 'Gas', '23.80 gal.', '121.00 cu.ft.', '203.70 in.', '74.90 ', '57.10 in.']
# https://www.carspecs.us/cars/2006/volkswagen/phaeton
# ['$6,927', nan, nan, '5.86 sec', '250 hp', 'full-time 4MOTION all wheel ', nan, nan, '14.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2008/volkswagen/r32
# ['$4,075', 2, 5, '7.93 sec', '170 hp', 'Front Wheel Drive ', '24 mpg', 'Gas', '14.50 gal.', nan, '165.80 in.', '69.30 ', '58.20 in.']
# https://www.carspecs.us/cars/2009/volkswagen/rabbit
# [nan, nan, nan, '7.07 sec', '200 hp', 'Front wheel drive ', nan, nan, '14.50 gal.', '109.30 cu.ft.', '165.80 in.', '69.30 ', '58.40 in.']
# https://www.carspecs.us/cars/2009/volkswagen/rabbit-gti-gti
# ['$3,916', nan, nan, '5.52 sec', '250 hp', ' All wheel drive  ', nan, 'Gas', '14.50 gal.', nan, '167.20 in.', '69.20 ', '57.70 in.']
# https://www.carspecs.us/cars/2008/volkswagen/rabbit-r32
# [nan, 4, 7, '7.32 sec', '283 hp', 'Front Wheel Drive ', nan, 'Gas', '20.50 gal.', nan, '202.50 in.', '76.90 ', '68.90 in.']
# https://www.carspecs.us/cars/2013/volkswagen/routan
# ['$24,945', 4, 7, '9.33 sec', '184 hp', 'Front Wheel Drive ', '25 mpg', 'Gas', '15.30 gal.', '123.90 cu.ft.', '185.10 in.', '72.40 ', '66.30 in.']
# https://www.carspecs.us/cars/2020/volkswagen/tiguan
# ['$24,225', 4, 5, '7.59 sec', '200 hp', 'All Wheel Drive ', '22 mpg', 'Gas', '16.90 gal.', nan, '174.50 in.', '71.20 ', '67.10 in.']
# https://www.carspecs.us/cars/2018/volkswagen/tiguan-limited
# [nan, 4, 5, nan, '280 hp', 'All Wheel Drive ', '19 mpg', 'Gas', '26.40 gal.', nan, '188.80 in.', '76.40 ', '68.20 in.']
# https://www.carspecs.us/cars/2017/volkswagen/touareg
# ['$10,700', nan, nan, nan, '225 hp', 'full-time 4XMOTION four-wheel ', nan, nan, '26.40 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2009/volkswagen/touareg-2
# [nan, nan, nan, '6.69 sec', '333 hp', 'full-time 4MOTION four-wheel ', nan, nan, '26.40 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/volkswagen/touareg-hybrid
# ['$13,646', nan, nan, '6.58 sec', '227 hp', ' Front wheel drive  ', nan, nan, '15.90 gal.', '104.50 cu.ft.', '167.40 in.', '70.20 ', '57.00 in.']
# https://www.carspecs.us/cars/2013/volvo/c30
# ['$20,188', nan, nan, '8.13 sec', '227 hp', 'front-wheel ', nan, nan, '16.40 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2013/volvo/c70
# ['$9,435', nan, nan, '7.34 sec', '227 hp', 'front-wheel ', nan, nan, '15.90 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2011/volvo/s40
# ['$36,050', 4, 5, '7.27 sec', '250 hp', 'Front Wheel Drive ', '27 mpg', 'Gas', '14.50 gal.', nan, '187.40 in.', '72.80 ', '56.30 in.']
# https://www.carspecs.us/cars/2020/volvo/s60
# [nan, nan, nan, '6.90 sec', '240 hp', ' All wheel drive  ', nan, 'Gas', '17.80 gal.', '105.00 cu.ft.', '182.60 in.', '74.80 ', '60.60 in.']
# https://www.carspecs.us/cars/2018/volvo/s60-cross-country
# ['$33,939', 4, 5, '7.15 sec', '240 hp', 'Front Wheel Drive ', '29 mpg', 'Gas', '17.80 gal.', nan, '185.70 in.', '73.40 ', '25.80 in.']
# https://www.carspecs.us/cars/2016/volvo/s60-inscription
# ['$39,183', 4, 5, '7.59 sec', '240 hp', 'Front Wheel Drive ', '29 mpg', 'Gas', '18.50 gal.', nan, '191.10 in.', '73.30 ', '21.50 in.']
# https://www.carspecs.us/cars/2016/volvo/s80
# ['$50,550', 4, 5, '6.64 sec', '316 hp', 'All Wheel Drive ', '25 mpg', 'Gas', '15.90 gal.', nan, '200.10 in.', '74.40 ', '26.50 in.']
# https://www.carspecs.us/cars/2020/volvo/s90
# ['$9,860', nan, nan, '6.74 sec', '227 hp', 'front-wheel ', nan, nan, '15.10 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2011/volvo/v50
# ['$39,650', 4, 5, '7.71 sec', '250 hp', 'Front Wheel Drive ', '27 mpg', 'Gas', '14.50 gal.', nan, '40.70 in.', '40.90 in.', '22.70 in.']
# https://www.carspecs.us/cars/2020/volvo/v60
# ['$45,700', 4, 5, '6.99 sec', '240 hp', 'All Wheel Drive ', nan, 'Gas', '17.80 gal.', nan, '38.50 in.', '73.40 ', '27.80 in.']
# https://www.carspecs.us/cars/2018/volvo/v60-cross-country
# ['$9,729', nan, nan, '7.41 sec', '235 hp', 'front-wheel ', nan, nan, '18.50 gal.', nan, nan, nan, nan]
# https://www.carspecs.us/cars/2010/volvo/v70
# ['$51,450', 4, 5, '7.96 sec', '250 hp', 'Front Wheel Drive ', '26 mpg', 'Gas', '15.90 gal.', nan, '45.40 in.', '43.30 in.', '26.80 in.']
# https://www.carspecs.us/cars/2020/volvo/v90
# [nan, nan, nan, '6.01 sec', '316 hp', ' All wheel drive  ', nan, 'Gas', '15.90 gal.', nan, '194.40 in.', '75.90 ', '60.70 in.']
# https://www.carspecs.us/cars/2017/volvo/v90-cross-country
# ['$33,700', 4, 5, '8.88 sec', '187 hp', 'Front Wheel Drive ', '27 mpg', 'Gas', '14.20 gal.', nan, '34.90 in.', '37.30 in.', '65.30 in.']
# https://www.carspecs.us/cars/2020/volvo/xc40
# ['$42,450', 4, 5, '7.02 sec', '250 hp', 'All Wheel Drive ', '23 mpg', 'Gas', '18.50 gal.', nan, '37.80 in.', '41.50 in.', '65.30 in.']
# https://www.carspecs.us/cars/2020/volvo/xc60
# ['$32,845', 4, 5, '7.70 sec', '240 hp', 'Front Wheel Drive ', '26 mpg', 'Gas', '18.50 gal.', nan, '42.90 in.', '44.50 in.', '27.40 in.']
# https://www.carspecs.us/cars/2016/volvo/xc70
# ['$50,850', 4, 7, '7.38 sec', '250 hp', 'All Wheel Drive ', '23 mpg', 'Gas', '18.80 gal.', '103.80 cu.ft.', '49.60 in.', '47.40 in.', '30.80 in.']
# https://www.carspecs.us/cars/2020/volvo/xc90

# %%
total_sales_df['Model_Merged'] = total_sales_df['Model'].str.strip()
total_sales_df['Model_Merged'] = total_sales_df['Model_Merged'].str.lower()
total_sales_df['Model_Merged'] = total_sales_df['Model_Merged'].str.replace('-','')
total_sales_df['Model_Merged'] = total_sales_df['Model_Merged'].str.replace('/','')
model_spec_df['Model_Merged'] = model_spec_df['Model'].str.strip()
model_spec_df['Model_Merged'] = model_spec_df['Model_Merged'].str.lower()
model_spec_df['Model_Merged'] = model_spec_df['Model_Merged'].str.replace('-','')
model_spec_df['Model_Merged'] = model_spec_df['Model_Merged'].str.replace('/','')

# %%
model_spec_sales_df = total_sales_df.merge(model_spec_df, how = 'left', on = 'Model_Merged')

# %% [markdown]
# drop uneeded columns and remove rows with a lot of na values

# %%
model_spec_sales_df.drop(labels=['Model_Merged', 'Model_y', 'url'], axis=1, inplace=True)
# model_spec_sales_df.dropna(how = ['price', 'doors', 'passengers', 'speed_sec', 'horsepower_hp', 'drive', 'mpg', 
#                                   'engine', 'tank_gal', 'volume_cuft', 'length_in', 'width_in', 'height_in'], inplace=True)

# %% [markdown]
# Clean drive feature

# %%
model_spec_sales_df['drive'] = model_spec_sales_df['drive'].str.lower()
model_spec_sales_df['drive'] = model_spec_sales_df['drive'].str.lstrip()
model_spec_sales_df['drive'] = model_spec_sales_df['drive'].str.rstrip()
#model_spec_sales_df = model_spec_sales_df.dropna()
model_spec_sales_df['drive'].value_counts()
# Out:
# front wheel drive                  240
# rear wheel drive                   137
# all wheel drive                    123
# four wheel drive                    27
# front-wheel                         11
# rear-wheel                           3
# automatic full-time all wheel        2
# attesa e-ts full-time all wheel      1
# full-time all wheel                  1
# Name: drive, dtype: int64

# %%
model_spec_sales_df['drive'] = model_spec_sales_df['drive'].str.replace('rear-wheel','rear wheel drive')
model_spec_sales_df['drive'] = model_spec_sales_df['drive'].str.replace('front-wheel','front wheel drive')
replace = ['full-time all wheel', 'attesa e-ts full-time all wheel', 'automatic full-time all wheel']

model_spec_sales_df['drive'] = model_spec_sales_df['drive'].str.replace(replace[1],'all wheel drive')
model_spec_sales_df['drive'] = model_spec_sales_df['drive'].str.replace(replace[2],'all wheel drive')
model_spec_sales_df['drive'] = model_spec_sales_df['drive'].str.replace(replace[2],'all wheel drive')
# for s in replace:
#     model_spec_sales_df['drive'] = model_spec_sales_df['drive'].str.replace(s,'all wheel drive')
model_spec_sales_df['drive'].value_counts()
# Out:
# front wheel drive      251
# rear wheel drive       140
# all wheel drive        126
# four wheel drive        27
# full-time all wheel      1
# Name: drive, dtype: int64

# %%
model_spec_sales_df.info()
model_spec_sales_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 680 entries, 0 to 679
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model_x        680 non-null    object
#  1   Total_Sales    680 non-null    float64
#  2   price          460 non-null    object
#  3   doors          425 non-null    object
#  4   passengers     425 non-null    object
#  5   speed_sec      419 non-null    object
#  6   horsepower_hp  539 non-null    object
#  7   drive          545 non-null    object
#  8   mpg            354 non-null    object
#  9   engine         519 non-null    object
#  10  tank_gal       525 non-null    object
#  11  volume_cuft    248 non-null    object
#  12  length_in      518 non-null    object
#  13  width_in       523 non-null    object
#  14  height_in      527 non-null    object
# dtypes: float64(1), object(14)
# memory usage: 85.0+ KB
#                Model_x  Total_Sales    price doors passengers speed_sec  \
# 0        Ford F-Series    9147816.0      NaN   NaN        NaN       NaN
# 1  Chevrolet Silverado    6685079.0      NaN   NaN        NaN       NaN
# 2         Toyota Camry    6221548.0  $28,430     4          5       NaN
# 3          Honda Civic    5009981.0  $21,750     4          5       NaN
# 4         Honda Accord    4943796.0  $24,020     4          5       NaN
#
#   horsepower_hp              drive     mpg engine    tank_gal    volume_cuft  \
# 0           NaN                NaN     NaN    NaN         NaN            NaN
# 1           NaN                NaN     NaN    NaN         NaN            NaN
# 2        208 hp  front wheel drive  52 mpg    Gas  13.20 gal.   99.90 cu.ft.
# 3        174 hp  front wheel drive  34 mpg    Gas  12.40 gal.   97.20 cu.ft.
# 4        192 hp  front wheel drive  33 mpg    Gas  14.80 gal.  105.60 cu.ft.
#
#     length_in width_in  height_in
# 0         NaN      NaN        NaN
# 1         NaN      NaN        NaN
# 2  192.10 in.   72.40   56.90 in.
# 3  177.90 in.   70.80   56.50 in.
# 4  192.20 in.   73.30   57.10 in.

# %%
replace_list = ['hp', 'mpg', 'gal.', 'cu.ft.', 'in.', ',', 'sec', '$', '$']
for s in replace_list:
    model_spec_sales_df = model_spec_sales_df.replace(s,'', regex=True) 
model_spec_sales_df['price'] = model_spec_sales_df['price'].str.replace('$','')
# Out:
# <ipython-input-20-eabc4894fe8e>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   model_spec_sales_df['price'] = model_spec_sales_df['price'].str.replace('$','')

# %%
num_cols = ['price', 'passengers', 'speed_sec', 'horsepower_hp', 'mpg', 'tank_gal', 'volume_cuft', 
            'width_in', 'length_in','height_in']
for col in num_cols:
    model_spec_sales_df[col] = model_spec_sales_df[col].apply (pd.to_numeric, errors='coerce')
model_spec_sales_df['doors'] = model_spec_sales_df[doors].apply (pd.to_numeric, errors='coerce')

# %%
model_spec_sales_df.info()
model_spec_sales_df.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 680 entries, 0 to 679
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Model_x        680 non-null    object
#  1   Total_Sales    680 non-null    float64
#  2   price          460 non-null    float64
#  3   doors          425 non-null    float64
#  4   passengers     425 non-null    float64
#  5   speed_sec      419 non-null    float64
#  6   horsepower_hp  539 non-null    float64
#  7   drive          545 non-null    object
#  8   mpg            354 non-null    float64
#  9   engine         519 non-null    object
#  10  tank_gal       525 non-null    float64
#  11  volume_cuft    248 non-null    float64
#  12  length_in      518 non-null    float64
#  13  width_in       523 non-null    float64
#  14  height_in      527 non-null    float64
# dtypes: float64(12), object(3)
# memory usage: 85.0+ KB
#                    Model_x  Total_Sales    price  doors  passengers  \
# 502      Infti Q40/G Sedan      15590.0      NaN    NaN         NaN
# 522               Lexus CT      13593.0      NaN    4.0         5.0
# 3              Honda Civic    5009981.0  21750.0    4.0         5.0
# 354                 BMW X6      59592.0  66600.0    4.0         5.0
# 98                Lexus IS     590505.0  38560.0    4.0         5.0
# 184              Acura TLX     217010.0  39400.0    4.0         5.0
# 233          Loln Town Car     154082.0      NaN    NaN         NaN
# 159           Dodge Dakota     265325.0  10415.0    NaN         NaN
# 87               GMC Yukon     660245.0  67700.0    4.0         7.0
# 590  Maserati Quattroporte       3968.0  99490.0    4.0         5.0
#
#      speed_sec  horsepower_hp              drive   mpg engine  tank_gal  \
# 502        NaN            NaN                NaN   NaN    NaN       NaN
# 522        NaN          134.0  front wheel drive  42.0    Gas      11.9
# 3          NaN          174.0  front wheel drive  34.0    Gas      12.4
# 354        NaN          335.0    all wheel drive  22.0    Gas      22.4
# 98        6.80          241.0   rear wheel drive  24.0    Gas      17.4
# 184       7.21          206.0  front wheel drive  26.0    Gas      17.2
# 233       8.14          239.0   rear wheel drive   NaN    Gas      19.0
# 159       8.82          210.0   rear wheel drive   NaN    NaN      22.0
# 87         NaN          420.0   rear wheel drive  17.0    Gas      26.0
# 590       4.59          424.0   rear wheel drive  19.0    Gas      21.1
#
#      volume_cuft  length_in  width_in  height_in
# 502          NaN        NaN       NaN        NaN
# 522         86.1      171.2      69.5       27.4
# 3           97.2      177.9      70.8       56.5
# 354          NaN      194.8      78.9       66.3
# 98          90.2      184.3      71.3       56.3
# 184         93.3      191.0      73.0       57.0
# 233        120.5      221.4      78.2       58.7
# 159          NaN        NaN       NaN        NaN
# 87           NaN       43.2      80.5       74.4
# 590          NaN      207.2      76.7       58.3

# %%
model_spec_sales_df.to_pickle('../data/model_spec_sales_df.pkl')
